# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext autotime

from ngram import tune, roc_scorer
from baselines import load_comments_and_labels, assemble_data
from deep_learning import make_MLP, DenseTransformer

from sklearn.pipeline import Pipeline
from sklearn.grid_search import RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from keras.wrappers.scikit_learn import KerasClassifier
from serialization import save_pipeline
import joblib
# Out:
# Using TensorFlow backend.

# %%
task = 'recipient'
path = '../../models/cv/'
n_max = 10000000
n_iter = 24
# Out:
# time: 2.12 ms

# %% [markdown]
# ### Load Annotated Data

# %%
data = load_comments_and_labels(task)
# Out:
# time: 1min 51s

# %%
X_train, y_train = assemble_data(data, 'comments', 'plurality', splits = ['train'])
X_dev, y_dev = assemble_data(data,  'comments', 'plurality', splits = ['dev'])
# Out:
# time: 25.1 ms

# %%
X_train = X_train[:n_max]
X_dev = X_dev[:n_max]
y_train = y_train[:n_max]
y_dev = y_dev[:n_max]
# Out:
# time: 1.54 ms

# %%
def save_best_estimator(cv, directory, name):
    params = cv.best_params_
    model = cv.estimator
    model = model.set_params(**params)
    save_pipeline(model, directory, name)
# Out:
# time: 1.86 ms

# %% [markdown]
# # Sklearn

# %% [markdown]
# ### Linear Model

# %%
alg = Pipeline([
    ('vect', CountVectorizer()),
    ('clf', LogisticRegression()),
])

param_grid = {
    'vect__max_features': (500, 5000, 10000, 50000, None), 
    'vect__ngram_range': ((1,5),),  
    'vect__analyzer' : ('char',),
    'clf__C' : (0.0001, 0.001, 0.01, 0.1, 1, 10),
}

linear_counts = tune (X_train, y_train, X_dev, y_dev, alg, param_grid, n_iter, roc_scorer, n_jobs = 6, verbose = True)
save_best_estimator(linear_counts, path, 'linear_counts')
# Out:
# Best parameters set found:
# {'clf__C': 10, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': None} 0.883319425654
#
#
# Grid scores:
# 0.82341 (+/-0.00000) for {'clf__C': 1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 50000}
# 0.81954 (+/-0.00000) for {'clf__C': 0.01, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 5000}
# 0.80201 (+/-0.00000) for {'clf__C': 1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 500}
# 0.82659 (+/-0.00000) for {'clf__C': 0.001, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': None}
# 0.82959 (+/-0.00000) for {'clf__C': 10, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 50000}
# 0.88332 (+/-0.00000) for {'clf__C': 10, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': None}
# 0.81832 (+/-0.00000) for {'clf__C': 0.01, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 500}
# 0.87496 (+/-0.00000) for {'clf__C': 0.001, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 10000}
# 0.83086 (+/-0.00000) for {'clf__C': 0.1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 500}
# 0.81886 (+/-0.00000) for {'clf__C': 1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 5000}
# 0.82169 (+/-0.00000) for {'clf__C': 0.1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 5000}
# 0.82673 (+/-0.00000) for {'clf__C': 0.1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 10000}
# 0.83433 (+/-0.00000) for {'clf__C': 0.001, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 500}
# 0.82581 (+/-0.00000) for {'clf__C': 10, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 10000}
# 0.84784 (+/-0.00000) for {'clf__C': 0.01, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': None}
# 0.85007 (+/-0.00000) for {'clf__C': 0.001, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 50000}
# 0.83150 (+/-0.00000) for {'clf__C': 1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 10000}
# 0.81322 (+/-0.00000) for {'clf__C': 0.0001, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 10000}
# 0.82141 (+/-0.00000) for {'clf__C': 10, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 5000}
# 0.81644 (+/-0.00000) for {'clf__C': 0.0001, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 5000}
# 0.84275 (+/-0.00000) for {'clf__C': 0.0001, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 50000}
# 0.83326 (+/-0.00000) for {'clf__C': 10, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 500}
# 0.82963 (+/-0.00000) for {'clf__C': 0.01, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': 50000}
# 0.88099 (+/-0.00000) for {'clf__C': 1, 'vect__analyzer': 'char', 'vect__ngram_range': (1, 5), 'vect__max_features': None}
# time: 30min 59s

# %%
alg = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', LogisticRegression()),
])

param_grid = {
    'vect__max_features': (500, 5000, 10000, 50000, None), 
    'vect__ngram_range': ((1,5),),  
    'vect__analyzer' : ('char',),
    'tfidf__sublinear_tf' : (True, False),
    'tfidf__norm' : (None, 'l2'),
    'clf__C' : (0.0001, 0.001, 0.01, 0.1, 1, 10),
}

linear_tfidf = tune (X_train, y_train, X_dev, y_dev, alg, param_grid, n_iter, roc_scorer, n_jobs = 6, verbose = True)
save_best_estimator(linear_tfidf, path, 'linear_tfidf')
# Out:
# Best parameters set found:
# {'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__C': 10, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'} 0.969655522426
#
#
# Grid scores:
# 0.72582 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 500, 'clf__C': 0.0001, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.96308 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 5000, 'clf__C': 1, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.93920 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__C': 0.1, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.95593 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 5000, 'clf__C': 0.001, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.69622 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__C': 0.0001, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.96876 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__C': 10, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.86471 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__C': 0.001, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.90043 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__C': 0.01, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.77295 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__C': 0.001, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.94872 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': None, 'clf__C': 0.1, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.85150 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 500, 'clf__C': 0.0001, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.95115 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__C': 0.01, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.95558 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': None, 'clf__C': 10, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.95141 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 500, 'clf__C': 10, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.94041 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 500, 'clf__C': 1, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.94840 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 500, 'clf__C': 1, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.75732 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': None, 'clf__C': 0.001, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.96966 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__C': 10, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.96631 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__C': 10, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.94745 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__C': 0.01, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.84246 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 500, 'clf__C': 0.001, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.77882 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': None, 'clf__C': 0.001, 'tfidf__sublinear_tf': False, 'vect__ngram_range': (1, 5), 'tfidf__norm': None}
# 0.84998 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': None, 'clf__C': 0.001, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# 0.91649 (+/-0.00000) for {'vect__analyzer': 'char', 'vect__max_features': 500, 'clf__C': 0.01, 'tfidf__sublinear_tf': True, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2'}
# time: 26min 13s

# %% [markdown]
# # Tensorflow/Keras

# %% [markdown]
# ### EDP

# %%
X_train, y_train = assemble_data(data, 'comments', 'empirical_dist', splits = ['train'])
X_dev, y_dev = assemble_data(data,  'comments', 'empirical_dist', splits = ['dev'])
# Out:
# time: 257 ms

# %%
X_train = X_train[:n_max]
X_dev = X_dev[:n_max]
y_train = y_train[:n_max]
y_dev = y_dev[:n_max]
# Out:
# time: 6.09 ms

# %%
n_edp_features = 10000

alg = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('to_dense', DenseTransformer()), 
    ('clf', KerasClassifier(build_fn=make_MLP, output_dim = 2, input_dim = n_edp_features)),
])

param_grid = {
    'vect__max_features': (n_edp_features,), 
    'vect__ngram_range': ((1,5),),  
    'vect__analyzer' : ('char',),
    'tfidf__sublinear_tf' : (True,),
    'tfidf__norm' : ('l2',),
    'clf__alpha' : (0.000000001, 0.0000001, 0.00001, 0.001, 0.01),
    'clf__hidden_layer_sizes' : ((), (50,), (50, 50), (50, 50, 10)),
    'clf__nb_epoch' : (2,4,8,16),
    'clf__batch_size': (200,),
}

edp_tfidf = tune (X_train, y_train, X_dev, y_dev, alg, param_grid, n_iter, roc_scorer, n_jobs = 1, verbose = True)
save_best_estimator(edp_tfidf, path, 'edp_tfidf')
# Out:
# Epoch 1/16
# 69490/69490 [==============================] - 9s - loss: 0.1220 - acc: 0.9447
# Epoch 2/16
# 69490/69490 [==============================] - 9s - loss: 0.0656 - acc: 0.9642
# Epoch 3/16
# 69490/69490 [==============================] - 9s - loss: 0.0583 - acc: 0.9688
# Epoch 4/16
# 69490/69490 [==============================] - 9s - loss: 0.0524 - acc: 0.9734
# Epoch 5/16
# 69490/69490 [==============================] - 9s - loss: 0.0472 - acc: 0.9762
# Epoch 6/16
# 69490/69490 [==============================] - 9s - loss: 0.0426 - acc: 0.9786
# Epoch 1/2
# 69490/69490 [==============================] - 5s - loss: 0.3324 - acc: 0.9220
# Epoch 2/2
# 69490/69490 [==============================] - 5s - loss: 0.2247 - acc: 0.9256
# 23000/23170 [============================>.] - ETA: 0sEpoch 1/4
# 69490/69490 [==============================] - 11s - loss: 0.1418 - acc: 0.9382
# Epoch 2/4
# 69490/69490 [==============================] - 8s - loss: 0.0673 - acc: 0.9627
# Epoch 3/4
# 69490/69490 [==============================] - 9s - loss: 0.0608 - acc: 0.9663
# Epoch 4/4
# 69490/69490 [==============================] - 9s - loss: 0.0555 - acc: 0.9708
# 23170/23170 [==============================] - 1s
# Epoch 1/2
# 69490/69490 [==============================] - 9s - loss: 0.1366 - acc: 0.9442
# Epoch 2/2
# 69490/69490 [==============================] - 8s - loss: 0.0777 - acc: 0.9609
# 23170/23170 [==============================] - 1s
# Epoch 1/4
# 69490/69490 [==============================] - 9s - loss: 0.1412 - acc: 0.9411
# Epoch 2/4
# 69490/69490 [==============================] - 8s - loss: 0.0682 - acc: 0.9621
# Epoch 3/4
# 69490/69490 [==============================] - 9s - loss: 0.0628 - acc: 0.9651
# Epoch 4/4
# 69490/69490 [==============================] - 9s - loss: 0.0588 - acc: 0.9675
# 23170/23170 [==============================] - 1s
# Epoch 1/2
# 69490/69490 [==============================] - 9s - loss: 0.1568 - acc: 0.9401
# Epoch 2/2
# 69490/69490 [==============================] - 9s - loss: 0.0681 - acc: 0.9619
# 23170/23170 [==============================] - 1s
# Epoch 1/2
# 69490/69490 [==============================] - 9s - loss: 0.1296 - acc: 0.9447
# Epoch 2/2
# 69490/69490 [==============================] - 9s - loss: 0.0720 - acc: 0.9610
# 23170/23170 [==============================] - 1s
#
# Best parameters set found:
# {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 4} 0.974301693238
#
#
# Grid scores:
# 0.95814 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 16}
# 0.94406 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.93777 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.97271 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 8}
# 0.97146 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 8}
# 0.92049 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.97381 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 4}
# 0.95164 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 16}
# 0.96855 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 16}
# 0.94087 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 4}
# 0.97109 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.96207 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 4}
# 0.96216 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 16}
# 0.97316 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 8}
# 0.97226 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.87565 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 8}
# 0.93473 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 8}
# 0.94482 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.83257 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.97430 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 4}
# 0.97058 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.97384 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 4}
# 0.97155 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# 0.96888 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'vect__analyzer': 'char', 'vect__max_features': 10000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'clf__nb_epoch': 2}
# time: 1h 19min 54s

# %%
n_edp_features = 200
alg = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('lsa', TruncatedSVD()),
    ('clf', KerasClassifier(build_fn=make_MLP, output_dim = 2, input_dim = n_edp_features)),
])

param_grid = {
    'vect__max_features': (50000,), 
    'vect__ngram_range': ((1,5),),  
    'vect__analyzer' : ('char',),
    'tfidf__sublinear_tf' : (True,),
    'tfidf__norm' : ('l2',),
    'lsa__n_components' : (n_edp_features,),
    'clf__alpha' : (0.000000001, 0.0000001, 0.00001, 0.001, 0.01),
    'clf__hidden_layer_sizes' : ((), (50,), (50, 50), (50, 50, 10)),
    'clf__nb_epoch' : (2, 4, 8, 16),
    'clf__batch_size': (200,),
}

edp_lsa = tune (X_train, y_train, X_dev, y_dev, alg, param_grid, n_iter, roc_scorer, n_jobs = 1, verbose = True)
save_best_estimator(edp_lsa, path, 'edp_lsa')
# Out:
# Epoch 1/2
# 69490/69490 [==============================] - 1s - loss: 0.1878 - acc: 0.9351
# Epoch 2/2
# 69490/69490 [==============================] - 0s - loss: 0.0810 - acc: 0.9565
# 23170/23170 [==============================] - 0s
# Epoch 1/2
# 69490/69490 [==============================] - 1s - loss: 0.2164 - acc: 0.9232
# Epoch 2/2
# 69490/69490 [==============================] - 1s - loss: 0.1193 - acc: 0.9256
# 23170/23170 [==============================] - 0s
# Epoch 1/8
# 69490/69490 [==============================] - 1s - loss: 0.3865 - acc: 0.9170
# Epoch 2/8
# 69490/69490 [==============================] - 0s - loss: 0.2305 - acc: 0.9268
# Epoch 3/8
# 69490/69490 [==============================] - 0s - loss: 0.1689 - acc: 0.9294
# Epoch 4/8
# 69490/69490 [==============================] - 0s - loss: 0.1410 - acc: 0.9328
# Epoch 5/8
# 69490/69490 [==============================] - 0s - loss: 0.1257 - acc: 0.9364
# Epoch 6/8
# 69490/69490 [==============================] - 0s - loss: 0.1155 - acc: 0.9396
# Epoch 7/8
# 69490/69490 [==============================] - 0s - loss: 0.1081 - acc: 0.9424
# Epoch 8/8
# 69490/69490 [==============================] - 0s - loss: 0.1024 - acc: 0.9448
# 20800/23170 [=========================>....] - ETA: 0sEpoch 1/16
# 69490/69490 [==============================] - 2s - loss: 0.3023 - acc: 0.9236
# Epoch 2/16
# 69490/69490 [==============================] - 1s - loss: 0.2021 - acc: 0.9256
# Epoch 3/16
# 69490/69490 [==============================] - 1s - loss: 0.1984 - acc: 0.9256
# Epoch 4/16
# 69490/69490 [==============================] - 1s - loss: 0.1965 - acc: 0.9256
# Epoch 5/16
# 69490/69490 [==============================] - 1s - loss: 0.1952 - acc: 0.9256
# Epoch 6/16
# 69490/69490 [==============================] - 1s - loss: 0.1942 - acc: 0.9256
# Epoch 7/16
# 69490/69490 [==============================] - 2s - loss: 0.1935 - acc: 0.9256
# Epoch 8/16
# 69490/69490 [==============================] - 2s - loss: 0.1928 - acc: 0.9256
# Epoch 9/16
# Epoch 6/16
# 69490/69490 [==============================] - 1s - loss: 0.0772 - acc: 0.9585
# Epoch 7/16
# 69490/69490 [==============================] - 1s - loss: 0.0767 - acc: 0.9589
# Epoch 8/16
# 69490/69490 [==============================] - 1s - loss: 0.0762 - acc: 0.9592
# Epoch 9/16
# 69490/69490 [==============================] - 1s - loss: 0.0758 - acc: 0.9597
# Epoch 10/16
# 69490/69490 [==============================] - 1s - loss: 0.0754 - acc: 0.9602
# Epoch 11/16
# 69490/69490 [==============================] - 1s - loss: 0.0750 - acc: 0.9605
# Epoch 12/16
# 69490/69490 [==============================] - 1s - loss: 0.0746 - acc: 0.9610
# Epoch 13/16
# 69490/69490 [==============================] - 1s - loss: 0.0743 - acc: 0.9612
# Epoch 14/16
# 69490/69490 [==============================] - 1s - loss: 0.0739 - acc: 0.9616
# Epoch 15/16
# 69490/69490 [==============================] - 1s - loss: 0.0736 - acc: 0.9616
# Epoch 16/16
# 69490/69490 [==============================] - 1s - loss: 0.0733 - acc: 0.9622
# 22600/23170 [============================>.] - ETA: 0sEpoch 1/8
# 69490/69490 [==============================] - 1s - loss: 0.2137 - acc: 0.9250
# Epoch 2/8
# 69490/69490 [==============================] - 1s - loss: 0.1310 - acc: 0.9256
# Epoch 3/8
# 69490/69490 [==============================] - 1s - loss: 0.1248 - acc: 0.9256
# Epoch 4/8
# 69490/69490 [==============================] - 1s - loss: 0.1221 - acc: 0.9438
# Epoch 5/8
# 69490/69490 [==============================] - 1s - loss: 0.1207 - acc: 0.9501
# Epoch 6/8
# 69490/69490 [==============================] - 1s - loss: 0.1197 - acc: 0.9508
# Epoch 7/8
# 69490/69490 [==============================] - 1s - loss: 0.1190 - acc: 0.9512
# Epoch 8/8
# 69490/69490 [==============================] - 1s - loss: 0.1183 - acc: 0.9516
# 22000/23170 [===========================>..] - ETA: 0sEpoch 1/16
# 69490/69490 [==============================] - 2s - loss: 0.1715 - acc: 0.9296
# Epoch 2/16
# 69490/69490 [==============================] - 1s - loss: 0.0790 - acc: 0.9578
# Epoch 3/16
# 69490/69490 [==============================] - 1s - loss: 0.0763 - acc: 0.9595
# Epoch 4/16
# 69490/69490 [==============================] - 1s - loss: 0.0740 - acc: 0.9608
# Epoch 5/16
# 69490/69490 [==============================] - 1s - loss: 0.0721 - acc: 0.9625
# Epoch 6/16
# 69490/69490 [==============================] - 1s - loss: 0.0708 - acc: 0.9639
# Epoch 7/16
# 69490/69490 [==============================] - 1s - loss: 0.0696 - acc: 0.9645
# Epoch 8/16
# 69490/69490 [==============================] - 2s - loss: 0.0684 - acc: 0.9651
# Epoch 9/16
# 69490/69490 [==============================] - 1s - loss: 0.0674 - acc: 0.9659
# Epoch 10/16
# 69490/69490 [==============================] - 2s - loss: 0.0664 - acc: 0.9664
# Epoch 11/16
# 69490/69490 [==============================] - 2s - loss: 0.0655 - acc: 0.9667
# Epoch 12/16
# 69490/69490 [==============================] - 1s - loss: 0.0648 - acc: 0.9670
# Epoch 13/16
# 69490/69490 [==============================] - 2s - loss: 0.0638 - acc: 0.9677
# Epoch 14/16
# 69490/69490 [==============================] - 1s - loss: 0.0633 - acc: 0.9680
# Epoch 15/16
# 69490/69490 [==============================] - 2s - loss: 0.0627 - acc: 0.9683
# Epoch 16/16
# 69490/69490 [==============================] - 1s - loss: 0.0622 - acc: 0.9687
# 23000/23170 [============================>.] - ETA: 0sEpoch 1/8
# 69490/69490 [==============================] - 1s - loss: 0.1900 - acc: 0.9282
# Epoch 2/8
# 69490/69490 [==============================] - 1s - loss: 0.0821 - acc: 0.9569
# Epoch 3/8
# 69490/69490 [==============================] - 1s - loss: 0.0802 - acc: 0.9572
# Epoch 4/8
# 69490/69490 [==============================] - 1s - loss: 0.0794 - acc: 0.9578
# Epoch 5/8
# 69490/69490 [==============================] - 1s - loss: 0.0787 - acc: 0.9578
# Epoch 6/8
# 69490/69490 [==============================] - 1s - loss: 0.0781 - acc: 0.9586
# Epoch 7/8
# 69490/69490 [==============================] - 1s - loss: 0.0775 - acc: 0.9588
# Epoch 8/8
# 69490/69490 [==============================] - 1s - loss: 0.0770 - acc: 0.9592
# 23000/23170 [============================>.] - ETA: 0sEpoch 1/8
# 69490/69490 [==============================] - 1s - loss: 0.2752 - acc: 0.9215
# Epoch 2/8
# 69490/69490 [==============================] - 1s - loss: 0.1962 - acc: 0.9256
# Epoch 3/8
# 69490/69490 [==============================] - 1s - loss: 0.1937 - acc: 0.9256
# Epoch 4/8
# 69490/69490 [==============================] - 1s - loss: 0.1925 - acc: 0.9256
# Epoch 5/8
# 69490/69490 [==============================] - 1s - loss: 0.1917 - acc: 0.9256
# Epoch 6/8
# 69490/69490 [==============================] - 1s - loss: 0.1913 - acc: 0.9256
# Epoch 7/8
# 69490/69490 [==============================] - 1s - loss: 0.1909 - acc: 0.9256
# Epoch 8/8
# 69490/69490 [==============================] - 1s - loss: 0.1907 - acc: 0.9256
# 22600/23170 [============================>.] - ETA: 0sEpoch 1/4
# 69490/69490 [==============================] - 1s - loss: 0.1877 - acc: 0.9307
# Epoch 2/4
# 69490/69490 [==============================] - 1s - loss: 0.0799 - acc: 0.9570
# Epoch 3/4
# 69490/69490 [==============================] - 1s - loss: 0.0777 - acc: 0.9582
# Epoch 4/4
# 69490/69490 [==============================] - 1s - loss: 0.0765 - acc: 0.9585
# 22600/23170 [============================>.] - ETA: 0sEpoch 1/4
# 69490/69490 [==============================] - 1s - loss: 0.3805 - acc: 0.9229
# Epoch 2/4
# 69490/69490 [==============================] - 0s - loss: 0.2273 - acc: 0.9272
# Epoch 3/4
# 69490/69490 [==============================] - 0s - loss: 0.1671 - acc: 0.9299
# Epoch 4/4
# 69490/69490 [==============================] - 0s - loss: 0.1400 - acc: 0.9332
# 19800/23170 [========================>.....] - ETA: 0sEpoch 1/2
# 69490/69490 [==============================] - 2s - loss: 0.1675 - acc: 0.9255
# Epoch 2/2
# 69490/69490 [==============================] - 1s - loss: 0.0862 - acc: 0.9272
# 21600/23170 [==========================>...] - ETA: 0sEpoch 1/2
# 69490/69490 [==============================] - 2s - loss: 0.1628 - acc: 0.9364
# Epoch 2/2
# 69490/69490 [==============================] - 1s - loss: 0.0780 - acc: 0.9582
# 21600/23170 [==========================>...] - ETA: 0sEpoch 1/2
# 69490/69490 [==============================] - 1s - loss: 0.2152 - acc: 0.9246
# Epoch 2/2
# 69490/69490 [==============================] - 1s - loss: 0.1315 - acc: 0.9256
# 22400/23170 [============================>.] - ETA: 0sEpoch 1/4
# 69490/69490 [==============================] - 2s - loss: 0.1601 - acc: 0.9372
# Epoch 2/4
# 69490/69490 [==============================] - 1s - loss: 0.0778 - acc: 0.9579
# Epoch 3/4
# 69490/69490 [==============================] - 1s - loss: 0.0760 - acc: 0.9587
# Epoch 4/4
# 69490/69490 [==============================] - 1s - loss: 0.0740 - acc: 0.9604
# 21600/23170 [==========================>...] - ETA: 0s
# Best parameters set found:
# {'clf__hidden_layer_sizes': (50, 50), 'clf__nb_epoch': 8, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200} 0.966683095507
#
#
# Grid scores:
# 0.95997 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95794 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95996 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'clf__nb_epoch': 8, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.50000 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'clf__nb_epoch': 16, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96528 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'clf__nb_epoch': 16, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95918 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'clf__nb_epoch': 16, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95892 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95700 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.94352 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'clf__nb_epoch': 16, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.92441 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96098 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95746 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 16, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96668 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50), 'clf__nb_epoch': 8, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96535 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 16, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95669 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 8, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96549 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'clf__nb_epoch': 16, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96249 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 8, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.93897 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 8, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.01, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96182 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 4, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95887 (+/-0.00000) for {'clf__hidden_layer_sizes': (), 'clf__nb_epoch': 4, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96028 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-05, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96103 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-09, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.95467 (+/-0.00000) for {'clf__hidden_layer_sizes': (50,), 'clf__nb_epoch': 2, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 0.001, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# 0.96528 (+/-0.00000) for {'clf__hidden_layer_sizes': (50, 50, 10), 'clf__nb_epoch': 4, 'vect__analyzer': 'char', 'vect__max_features': 50000, 'clf__batch_size': 200, 'tfidf__sublinear_tf': True, 'clf__alpha': 1e-07, 'vect__ngram_range': (1, 5), 'tfidf__norm': 'l2', 'lsa__n_components': 200}
# time: 2h 15min 2s
