# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import glob
import bz2
from pprint import pprint
import json
import os
import csv
import multiprocessing as mp
import time

# %% [markdown]
# scp stat1003.eqiad.wmnet:/srv/ellery/talk_diffs/enwiki-20160113-pages-meta-history10.xml-*.bz2 ./wikipedia/data/

# %%
rsync -av /srv/public-datasets/enwiki/user_talk_diffs stat1002.wikimedia.org::a/home/ellery
        
rsync -av stat1003.wikimedia.org::srv/public-datasets/enwiki/user_talk_diffs .

# %%
path_glob = '../data/enwiki-20160113-pages-meta-history10.xml-*.bz2'

# %%
output_dir = '../data'

# %%
files = glob.glob(path_glob)

# %%
def get_features(obj):
    f = {}
    if 'comment' in obj:
        f['rev_comment'] = obj['comment']
        
    f['insert_only'] = 1
    if 'diff' in obj:
        if 'ops' in obj['diff']:
            for e in obj['diff']['ops']:
                if e['name'] == 'insert':
                    if 'tokens' in e:
                        insertion = ''.join(e['tokens'])
                        if len(insertion) > 0:
                            f['insertion'] = insertion
                else:
                    f['insert_only'] = 0
    if 'id' in obj:
        f['rev_id'] = obj['id']
        
    if 'page' in obj:
        if 'id' in obj['page']:
            f['page_id'] = obj['page']['id']
        if 'title' in obj['page']:
            f['page_title'] = obj['page']['title']
            
    if 'timestamp' in obj:
        f['rev_timestamp'] = obj['timestamp']
        
        
    if 'user' in obj:
        if 'id' in obj['user']:
            f['user_id'] = obj['user']['id']
        if 'text' in obj['user']:
            f['user_text'] = obj['user']['text']
    return f

# %%
def convert(infile):
    outfile = os.path.join(output_dir, infile.split('/')[-1].replace('bz2', 'tsv.bz2'))
    with bz2.open(infile, 'rt') as fin, bz2.open(outfile, 'wt') as fout:
        fieldnames = ['rev_comment', 'insertion', 'insert_only', 'rev_id', 'page_id', 'page_title', 'rev_timestamp', 'user_id', 'user_text']
        writer = csv.DictWriter(fout, fieldnames=fieldnames, delimiter='\t')
        writer.writeheader()
        for line in fin:
            obj = json.loads(line)
            f = get_features(obj)
            writer.writerow(f)

# %%
p = mp.Pool(mp.cpu_count())
p.map(convert, files)
# Out:
# [None, None, None, None, None, None, None, None]

# %%
df = pd.read_csv(bz2.open(outfile, 'rt'), sep = '\t')

# %%
df.shape
# Out:
# (59825, 9)

# %%
df[df['insert_only'] == 1].head(100)
# Out:
#                                             rev_comment  \
# 0       User talk:Ambi moved to User talk:Ambi/Archive3
# 120                                          your tests
# 123   blank ancient IP talk page posts per [[Wikiped...
# 124     Welcome to Wikipedia, [[User: 81.86.251.101]] !
# 125   blank ancient IP talk page warnings, Replaced:...
# 126                               Hey there, anarchist!
# 150                                                 NaN
# 156                                        Navbar thing
# 168                                           your test
# 169                                                 NaN
# 176                                             Welcome
# 178                                                 NaN
# 183   blank ancient IP talk page posts per [[Wikiped...
# 184   Please don't post newspaper articles to Wikipe...
# 185   You can't arbitrarily come in and revert that ...
# 186                                                 NaN
# 188                                                 NaN
# 192                                           your test
# 303                                                 NaN
# 376                                             welcome
# 381                Please don't post spam on Wikipedia.
# 383   User talk:Kirynflare moved to The super online...
# 384                              remove broken redirect
# 385                                             welcome
# 462                                        test message
# 464   blank ancient IP talk page posts per [[Wikiped...
# 465                                           vandalism
# 472                                                 NaN
# 476                                                 NaN
# 1857                                                NaN
# ...                                                 ...
# 3866                                            Welcome
# 3868                                            welcome
# 4711                                            welcome
# 4721                                                NaN
# 4732                                            welcome
# 4737                                                NaN
# 4738  blank ancient IP talk page posts per [[Wikiped...
# 4739           first 5 days of archive 12. 17-21 August
# 4747                                            welcome
# 4751  What is the source of the pictures you have be...
# 4754                                            welcome
# 4756                                            welcome
# 4759                       [[WP:AES|←]]Blanked the page
# 4760                                           `welcome
# 4820  Clean up of my comment page (all comments were...
# 4822                       [[WP:AES|←]]Blanked the page
# 4826                                                NaN
# 4827                                            welcmoe
# 4829                                            welcome
# 4831                                          your test
# 4833  blank ancient IP talk page warnings, Replaced:...
# 4834                                          your test
# 4835           blanking/categorizing stale IP talk page
# 4836                                         your tests
# 4845                                                NaN
# 4881                       [[WP:AES|←]]Blanked the page
# 4883                       [[WP:AES|←]]Blanked the page
# 4902                                            welcome
# 4904                                          your test
# 4906  blank ancient IP talk page warnings per [[Wiki...
#
#                                               insertion  insert_only  \
# 0               #REDIRECT [[User talk:Ambi/Archive3]]\n            1
# 120   {{test}} P.S.: warning: if you keep making tes...            1
# 123                                                 NaN            1
# 124   Dear [[User: 81.86.251.101]],\n\nWelcome to Wi...            1
# 125                                                 NaN            1
# 126   Welcome to Wikipedia, Carlton.  You will proba...            1
# 150   == Note to self ==\n\nI do not understand the ...            1
# 156   [[User talk:Ilyanep|Ilyanep's Talk]] , [[User ...            1
# 168   {{test}} -- [[User:Infrogmation|Infrogmation]]...            1
# 169                                                 NaN            1
# 176   ==[[Wikipedia:Welcome, newcomers|Welcome]] to ...            1
# 178   Thanks for experimenting with Wikipedia. Your ...            1
# 183                                                 NaN            1
# 184   Please don't post newspaper articles to Wikipe...            1
# 185   We;ve had this discussion about the Clitoris a...            1
# 186                                                 NaN            1
# 188                                                 NaN            1
# 192                                            {{test}}            1
# 303                                                 NaN            1
# 376                                 {{User:Meelar/wel}}            1
# 381   Please don't post spam on Wikipedia.  [[User:R...            1
# 383   #REDIRECT [[The super online game-Legend Arena...            1
# 384                                                 NaN            1
# 385                                 {{User:Meelar/wel}}            1
# 462   {{test}} [[User:Andris|Andris]] 09:21, Aug 24,...            1
# 464                                                 NaN            1
# 465   Please do not create articles that are not ser...            1
# 472                                <hr><hr><hr><hr><hr>            1
# 476                                                 NaN            1
# 1857  Please stop vandalizing Wikipedia pages. It is...            1
# ...                                                 ...          ...
# 3866  ==[[Wikipedia:Welcome, newcomers|Welcome]] to ...            1
# 3868                                {{User:Meelar/wel}}            1
# 4711                                {{User:Meelar/wel}}            1
# 4721                                                NaN            1
# 4732                                {{User:meelar/wel}}            1
# 4737  Thanks for experimenting with Wikipedia. Your ...            1
# 4738                                                NaN            1
# 4739  >>[[User talk:Angela/Archive13]]\n\n== Protect...            1
# 4747                                {{User:Meelar/wel}}            1
# 4751  What is the source of the pictures you have be...            1
# 4754                                {{User:Meelar/wel}}            1
# 4756                                {{User:Meelar/wel}}            1
# 4759                                                NaN            1
# 4760                                {{User:Meelar/wel}}            1
# 4820                                                NaN            1
# 4822                                                NaN            1
# 4826  Hi, welcome to Wikipedia.  Unfortunately, I ha...            1
# 4827                                {{User:Meelar/wel}}            1
# 4829                                {{User:Meelar/wel}}            1
# 4831                                           {{test}}            1
# 4833                                                NaN            1
# 4834                                           {{test}}            1
# 4835                                                NaN            1
# 4836                                           {{test}}            1
# 4845                                                NaN            1
# 4881                                                NaN            1
# 4883                                                NaN            1
# 4902                                {{User:Meelar/wel}}            1
# 4904  {{test}} -- [[User:Infrogmation|Infrogmation]]...            1
# 4906                                                NaN            1
#
#          rev_id  page_id              page_title         rev_timestamp  \
# 0       5404708   925005    Ambi~enwiki/Archive4  2004-08-24T04:07:52Z
# 120     5404915   925015            66.57.43.214  2004-08-24T04:18:26Z
# 123   259804119   925015            66.57.43.214  2008-12-23T22:57:29Z
# 124    16716724   925016           81.86.251.101  2004-08-24T04:18:31Z
# 125   257862579   925016           81.86.251.101  2008-12-14T07:17:27Z
# 126     5456045   925045                Carltonh  2004-08-24T04:34:01Z
# 150     5405319   925078  Ilyanep/Talk Archive 3  2004-08-24T04:53:51Z
# 156     6054324   925086              Ilyanep/TA  2004-08-24T04:58:22Z
# 168     5979548   925096            64.12.117.18  2004-08-24T05:08:13Z
# 169     6020861   925096            64.12.117.18  2004-09-19T02:22:21Z
# 176    16716812   925134      Ricardo E. Trelles  2004-08-24T05:21:52Z
# 178     7079049   925148           24.245.41.111  2004-08-24T05:28:55Z
# 183   259678860   925148           24.245.41.111  2008-12-23T07:03:47Z
# 184    16716872   925214            69.75.254.11  2004-08-24T05:55:29Z
# 185     5413054   925268          Jmieres~enwiki  2004-08-24T06:12:18Z
# 186     5413079   925268          Jmieres~enwiki  2004-08-24T15:41:37Z
# 188    16716923   925268          Jmieres~enwiki  2004-08-26T21:11:55Z
# 192     5558921   925291            203.14.53.46  2004-08-24T06:20:03Z
# 303    41983713   925291            203.14.53.46  2006-03-03T01:10:24Z
# 376     5415422   925383             UltimaGecko  2004-08-24T06:57:14Z
# 381    16717031   925385            83.16.52.115  2004-08-24T06:58:53Z
# 383    16717035   925391              Kirynflare  2004-08-24T07:01:49Z
# 384    22849794   925391              Kirynflare  2005-09-08T16:29:18Z
# 385     5428916   925405                   Allyn  2004-08-24T07:14:10Z
# 462    16717166   925554           64.161.177.57  2004-08-24T09:21:29Z
# 464   259482533   925554           64.161.177.57  2008-12-22T06:10:23Z
# 465     5539267   925626          220.244.224.40  2004-08-24T10:13:31Z
# 472     5421055   925653                 Pablo X  2004-08-24T10:40:35Z
# 476     8036573   925653                 Pablo X  2004-09-09T09:24:33Z
# 1857    5409543   925697           GookKiller900  2004-08-24T11:17:48Z
# ...         ...      ...                     ...                   ...
# 3866   16717954   926519         Apostrophicfolk  2004-08-24T17:51:56Z
# 3868    5908482   926523            Thunderbrand  2004-08-24T17:54:47Z
# 4711   16718000   926568                 Addaone  2004-08-24T18:14:22Z
# 4721   62975215   926568                 Addaone  2006-07-10T02:08:03Z
# 4732   16718018   926587           Simmer~enwiki  2004-08-24T18:21:41Z
# 4737   16718049   926622            64.252.49.85  2004-08-24T18:32:27Z
# 4738  259679748   926622            64.252.49.85  2008-12-23T07:10:40Z
# 4739    5520364   926623        Angela/Archive12  2004-08-24T18:32:28Z
# 4747   16718053   926626               Gigamorph  2004-08-24T18:33:04Z
# 4751    8322650   926631                    Guya  2004-08-24T18:33:29Z
# 4754   16718060   926633                     PGD  2004-08-24T18:33:42Z
# 4756   16718062   926636          Intelligentsia  2004-08-24T18:34:28Z
# 4759  361404818   926636          Intelligentsia  2010-05-11T03:02:08Z
# 4760    5579085   926648              Cavebear42  2004-08-24T18:36:38Z
# 4820  357774713   926648              Cavebear42  2010-04-23T06:13:21Z
# 4822  427084847   926648              Cavebear42  2011-05-02T16:01:34Z
# 4826   16718081   926656          HoneyKnowsBest  2004-08-24T18:39:20Z
# 4827   16718093   926670                 Kevouze  2004-08-24T18:43:19Z
# 4829   16718095   926673                  Jgille  2004-08-24T18:44:00Z
# 4831   16718098   926676            80.48.140.71  2004-08-24T18:45:26Z
# 4833  257917159   926676            80.48.140.71  2008-12-14T15:28:04Z
# 4834   16718100   926678          209.178.130.73  2004-08-24T18:46:05Z
# 4835   42433339   926678          209.178.130.73  2006-03-06T04:59:00Z
# 4836    5416993   926682         216.235.148.194  2004-08-24T18:47:09Z
# 4845   30371646   926682         216.235.148.194  2005-12-06T18:46:42Z
# 4881  207373030   926682         216.235.148.194  2008-04-22T15:12:06Z
# 4883  207373722   926682         216.235.148.194  2008-04-22T15:15:42Z
# 4902   16718111   926692                   Elsrj  2004-08-24T18:48:39Z
# 4904   16718115   926697           68.86.193.197  2004-08-24T18:50:27Z
# 4906  258271804   926697           68.86.193.197  2008-12-16T02:50:50Z
#
#       user_id                        user_text
# 0       13040  Vanished user 5zariu3jisj0j4irj
# 120      4444                     Infrogmation
# 123    196446                           BD2412
# 124     63672                           PFHLai
# 125    196446                           BD2412
# 126     45825                          Jdavidb
# 150     10837                          Ilyanep
# 156     10837                          Ilyanep
# 168      4444                     Infrogmation
# 169       NaN                     64.12.116.10
# 176     29048                        Sam Spade
# 178     10837                          Ilyanep
# 183    196446                           BD2412
# 184     13800                            RickK
# 185     13800                            RickK
# 186     38068                   Jmieres~enwiki
# 188     38068                   Jmieres~enwiki
# 192     13800                            RickK
# 303       NaN                     203.14.53.46
# 376     31618                           Meelar
# 381     13800                            RickK
# 383     96558                       Kirynflare
# 384     23999                              Jni
# 385     31618                           Meelar
# 462     47713                           Andris
# 464    196446                           BD2412
# 465     91707                           Livajo
# 472     96604                          Pablo X
# 476     96604                          Pablo X
# 1857    91707                           Livajo
# ...       ...                              ...
# 3866    29048                        Sam Spade
# 3868    31618                           Meelar
# 4711    31618                           Meelar
# 4721    89244                          Addaone
# 4732    31618                           Meelar
# 4737    10837                          Ilyanep
# 4738   196446                           BD2412
# 4739     8551                           Angela
# 4747    31618                           Meelar
# 4751     1591                           SimonP
# 4754    31618                           Meelar
# 4756    31618                           Meelar
# 4759    52383                   Intelligentsia
# 4760    31618                           Meelar
# 4820    86284                       Cavebear42
# 4822    86284                       Cavebear42
# 4826    13800                            RickK
# 4827    31618                           Meelar
# 4829    31618                           Meelar
# 4831    31280                          Texture
# 4833   196446                           BD2412
# 4834    31280                          Texture
# 4835   922334                        Tawkerbot
# 4836    31280                          Texture
# 4845      NaN                  216.235.148.194
# 4881      NaN                  216.235.148.194
# 4883      NaN                  216.235.148.194
# 4902    31618                           Meelar
# 4904     4444                     Infrogmation
# 4906   196446                           BD2412
#
# [100 rows x 9 columns]

# %%
for i, r in df[df['insert_only'] == 1][:100].iterrows():
    print(r['insertion'])
    print('\n\n\n\n')
# Out:
# #REDIRECT [[User talk:Ambi/Archive3]]
#
#
#
#
#
#
# {{test}} P.S.: warning: if you keep making tests in the middle of articles, it can be considered vandalism and may result in your being blocked from editing. -- [[User:Infrogmation|Infrogmation]] 04:18, 24 Aug 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# Dear [[User: 81.86.251.101]],
#
# Welcome to Wikipedia !  Your test at [[Gastrointestinal tract]] have worked, eh ?  Please stop, and instead, continue with your testing at [[Wikipedia:Sandbox]].
#
# Please consider [[Wikipedia:Why create an account?|setting up your own account]].  It's more fun this way.  :-)
#
# Happy editing !<br>
# -- [[User:PFHLai|PFHLai]] 04:18, 2004 Aug 24 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# Welcome to Wikipedia, Carlton.  You will probably never get out. :) [[User:Jdavidb|Jdavidb]] 04:34, 24 Aug 2004 (UTC)
#
#
#
#
#
# == Note to self ==
#
# I do not understand the meaning or the fundamental background of your words, or If I do, I stand in shock and disbelief [[User:Ilyanep|Ilyanep]] [[User talk:Ilyanep|(Talk)]] 17:13, 23 Jul 2004 (UTC)
#
# ----
#
# == Sandbox ==
#
# You said in your edit subject 'rv all this vandalism' but it was the sandbox. It's not vandalism to test edits. I did not make a personal attack. Email thegolem@tesco.net for a discussion about it.
# :Sorry, but I meant that some anonymous users had deleted the <nowiki>{{sandbox}}</nowiki> message and also created an unusally long one-line string of 'y's, which was hard to clean up, and I had to go at least 5 revisions back (more) to delete all that and add the notice back. Sorry for any confusion that may have caused. [[User:Ilyanep|Ilyanep]] [[User talk:Ilyanep|(Talk)]] 18:22, 23 Jul 2004 (UTC)
#
# ==Rendering==
# Hello.  Sorry that was impolite of me to make a comment like that on a ''public'' page.  I've deleted that bit.  Um, yes, it is basically just the tables.  Some of the text floats over the borders you've got and, in some instances, this means that you've got two layers of text overlapping making it very hard to read.
#
# So, on the front tab ''Ilyanep's page'' the ''some more stuff'' box runs entirely over ''some quotes''.  It does look quite bad.  I'm using IE6.0.2800 and a relatively small by today's standards, 17inch monitor.
#
# At any rate, I've you to blame for the ridiculous signature I've ended up with, since you sent me off on a trail of user page investigation, some of which taught me tips I've now abused to create this carbuncle --[[User:Bodnotbod|[[User:Bodnotbod|<font size=6>b</font><font size=5>o</font>d<small>not</small>bo<font size=6>d</font>]]  [[User talk:Bodnotbod|<font color=black>(</font><font size=2>TALK</font><font size=4>Q</font><font size=1>uietly</font><font size=6><font color=black>)</font>]]]] 05:34, Jul 28, 2004 (UTC)
#
# :Hi, it's okay about the comment on the public page, I don't mind. I took a look at it in IE and it looked fine. I'm using a 17 inch monitor at 1152x768 resolution. I'll try to make it look okay in 1024x640 or whatever that resolution is. [[User:Ilyanep|Ilyanep]] [[User talk:Ilyanep|(Talk)]] 16:45, 28 Jul 2004 (UTC)
#
# ::OK, I'm at 1024x768.  Let me know if you want to have a look at it in the future. Regards --[[User:Bodnotbod|[[User:Bodnotbod|<font size=4><b>b</b></font><font size=2>odnotbo</font><font size=4><b>d</b></font>]]    [[User talk:Bodnotbod|<font size=0>......TALK</font><font size=3>Q</font><font size=0>uietly</font><font size=4><font color=black>)</font>]]]] 23:53, Jul 28, 2004 (UTC)
#
# == Misspellings ==
#
# Just a quick note from a perfectionist: on your user page, "male" is not capitalized, and you may want to have a look at the "Note to self" section of your talk page ;-) [[User:Mike Storm|[[User:Mike Storm|Mike Storm]] <small>[[User talk:Mike Storm|(Talk)]]</small>]] 16:54, 29 Jul 2004 (UTC)
#
# :Alright thanks :D. [[User:Ilyanep|Ilyanep]] [[User talk:Ilyanep|(Talk)]] 19:00, 29 Jul 2004 (UTC)
#
#
#
# == Alexa ==
#
# Alexa has a feature where you can put your logo into an alexa toolbar and distribute it to visitors on your site. Perhaps we should try it? [[User:Ilyanep|Ilyanep]] [[User talk:Ilyanep|(Talk)]] 21:12, 22 Jul 2004 (UTC)
#
# :Can you provide a link to the feature so we can see what it does exactly? [[User:Mike Storm|[[User:Mike Storm|Mike Storm]] <small>[[User talk:Mike Storm|(Talk)]]</small>]] 00:25, 23 Jul 2004 (UTC)
#
# ::I think it refers to the [http://download.alexa.com/index.cgi Alexa toolbar]. I personally dislike 3rd-party toolbars, and as I don't use Internet Explorer but Firefox, it probably doesn't even work. -- [[User:Solitude|Solitude]] 10:22, 23 Jul 2004 (UTC)
#
# :::Yeah its an IE thing. [[User:Pcb21|Pcb21|]] [[User_talk:Pcb21|Pete]] 10:36, 23 Jul 2004 (UTC)
# :Maybe someone could make up a Wikipedia skin for Mozilla? <small>Although I am rather attached to my "Vorkosigan Comconsole" :-)</small> --[[User:Phil Boswell|Phil]] | [[User talk:Phil Boswell|Talk]] 13:47, Jul 23, 2004 (UTC)
#
# ::Second of all, a wp skin for Mozilla would so totally rock!
#
# :::First of all, I use Mozilla, not IE. Second of all, it has a feature where you can add you logo into an alexa toolbar and distribute it, it's something like Alexa associates or something.
#
# ::::Hi. I needed to clear out the village pump and there didn't seem to be a good place to put this. If this is a feature request, you might want to put it at [http://sourceforge.net/tracker/index.php?func=browse&group_id=34373&atid=411195&set=custom&_assigned_to=0&_status=1&_category=100&_group=100&order=open_date&sort=DESC&offset=0 sourceforge]. If it's related just to searching, then maybe [[Wikipedia:External search engines]] would be a better place. I'll leave it to you to find a home for it if you think it needs further discussion. [[User:Angela|Angela]][[user talk:Angela|.]] 18:56, Jul 30, 2004 (UTC)
#
# == Contrib chart ==
#
# Done. [[:Image:Ilyanepbyhour.png]]. [[User:VeryVerily|V]][[User talk:VeryVerily|<font color=green>V</font>]] 07:40, 2 Aug 2004 (UTC)
# :Thanks a lot [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 16:23, 2 Aug 2004 (UTC)
#
# [[:Image:Ilyanep contribution graph.png]] updated. [[User:Fredrik|Fredrik]] | [[User talk:Fredrik|talk]] 18:01, 2 Aug 2004 (UTC)
# :And thanks a lot to you too :D. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 18:04, 2 Aug 2004 (UTC)
#
# I just checked and it's definitely been updated.  Maybe you're browser is caching images?  You could try Reload/Refresh. [[User:VeryVerily|V]][[User talk:VeryVerily|<font color=green>V</font>]] 21:56, 2 Aug 2004 (UTC)
# :Perhaps...I'll try in a sec. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 22:12, 2 Aug 2004 (UTC)
#
# ==Rendering==
#
# Hello.  I think it looks better now than it did although it's hard to remember exaclty what I was seeing before.  However ''what is Ilyanepo reading'' still goes over into the ''some quotes'' section so that they share a right border and the text is one layered on top of the other.  Under your ''watch'' tab the box with some users names in and ''things of interest'' also overlap, one on top of the other to the extent that I can't read the content. Hope this helps. --[[User:Bodnotbod|[[User:Bodnotbod|<font size=4><b>b</b></font><font size=2>odnotbo</font><font size=4><b>d</b></font>]]    [[User talk:Bodnotbod|<font size=0>......TALK</font><font size=3>Q</font><font size=0>uietly</font><font size=4><font color=black>)</font>]]]] 19:00, Aug 2, 2004 (UTC)
# :I'm not sure what's up. The width for the watch boxes are set at 50%. and with percentage values on my main page. Perhaps it's the length messing up. I'll check it out. Thanks for your help. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 19:03, 2 Aug 2004 (UTC)
#
# == Thermometer ==
#
# More like [[User:Ilyanep|this?]] - [[User:Texture|<font color=red>T&#949;x</font>]][[User Talk:Texture|<font color=blue>&#964;</font>]][[User:Texture|<font color=red>ur&#949;</font>]] 21:16, 2 Aug 2004 (UTC)
# :Actually, if you see that empty space to the right of the Watching/Reading tables and below the quotes table, I want it to go in there, while the tables stay the same length. (btw, the table with the thermometer is currently in comment tags) [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 21:17, 2 Aug 2004 (UTC)
#
# Ok. Add a second table around your "Some Quotes" table with no border.  (Makes sure the original has no width or align.)  Add the graphic after the "Some Quotes" table but inside the new one you created. - [[User:Texture|<font color=red>T&#949;x</font>]][[User Talk:Texture|<font color=blue>&#964;</font>]][[User:Texture|<font color=red>ur&#949;</font>]] 21:20, 2 Aug 2004 (UTC)
#
# You may need a br between the two. - [[User:Texture|<font color=red>T&#949;x</font>]][[User Talk:Texture|<font color=blue>&#964;</font>]][[User:Texture|<font color=red>ur&#949;</font>]] 21:21, 2 Aug 2004 (UTC)
#
# :Ok, thanks a lot[[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 21:22, 2 Aug 2004 (UTC)
#
# That better? - [[User:Texture|<font color=red>T&#949;x</font>]][[User Talk:Texture|<font color=blue>&#964;</font>]][[User:Texture|<font color=red>ur&#949;</font>]] 21:48, 2 Aug 2004 (UTC)
#
# :Yes, much much much much much. Thank you very much. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 21:50, 2 Aug 2004 (UTC)
#
# ==Name==
# Are you sure your name shouldn't be something like "&Iota;&lambda;&eta;&alpha;&nu;&epsilon;&pi;" rather than "Il&#947;&#945;&#951;&#949;&#961;" which is probably pronounced something like "I-?-ga-ee-er"? (And "&Tau;&alpha;&lambda;&kappa;" instead of "T&#945;l&#954;"? Not sure what the greek equivalent of "a" in "talk" is.) [[User:Cyp|&#922;&#963;&#965;&#960; ''Cyp'']] [[User talk:Cyp|&nbsp;]] 21:34, 2 Aug 2004 (UTC)
#
# :I know. I was looking at asthetics rather than pronounciation. My thing would be Il-ga-ee-er, however isn't kappa pronounced k? therefore, talk would be talk? [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 21:36, 2 Aug 2004 (UTC)
#
# ::Yes, "&#954;" is pronounced "k". But there's no greek letter "l". With "&#932;&#945;l&#954;", I was suggesting "l" &rarr; "&#955;". (Thanks for the 'nice polyhedra' comment.) [[User:Cyp|&#922;&#963;&#965;&#960; ''Cyp'']] [[User talk:Cyp|&nbsp;]] 21:46, 2 Aug 2004 (UTC)
#
# :::Your welcome, good day. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 21:48, 2 Aug 2004 (UTC)
# :::)CTU( 4002 guA 2 ,94:12 [[User talk:Ilyanep|<font color="#333333">)&kappa;l&alpha;T(</font>]] [[User:Ilyanep|<font color="grey">&rho;&epsilon;&eta;&alpha;&gamma;lI</font>]] .yad doog ,emolcew yuoY
#
# ::::Yllautca, ereh s'ti doog thgin, ton doog yad. [[User:Cyp|&#928;&#965;&#963;&#954; Pyc]] [[User talk:Cyp|&nbsp;]] 21:51, 2 Gua 2004 (CTU)
#
# ::::: )CTU( 4002 guA 2 ,94:12 [[User talk:Ilyanep|<font color="#333333">)&kappa;l&alpha;T(</font>]] [[User:Ilyanep|<font color="grey">&rho;&epsilon;&eta;&alpha;&gamma;lI</font>]] llew ho.
#
# ==Contributions==
#
# Well, I live in the country, and it's summer, so I have lots of free time on the computer. When I'm not there, I'm swimming or hanging out with my friends. Feel free to drop me a line anytime; I like hearing from people. :-) [[User:TheCustomOfLife|Mike H]] 02:21, Aug 3, 2004 (UTC)
# :I'm sure I will [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 02:23, 3 Aug 2004 (UTC)
# ::It's a nice diversion, surely. Sometimes when the editing gets boring, you need to talk to people. [[User:TheCustomOfLife|Mike H]] 17:57, Aug 6, 2004 (UTC)
#
# ==WikiStress==
# Conv with Lucky 6.9 @ [[User talk:Lucky 6.9#WikiStress|His Talk Page]] [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 02:23, 3 Aug 2004 (UTC)
# ==Devil Sticks==
# What's up with all the orphaned redirects to a nonexistant article? Try Devil stick as opposed to Devil Stick. &#8212; Il&#947;&#945;&#951;&#949;&#961; (T&#945;l&#954;) 06:41, 2 Aug 2004 (UTC)
#
# Moved page to 'Devil Sticks' - neither or both terms should be capitalized.
#
# since I expanded the article to encompass the sport/art of Devil Sticks as a whole, it should not be 'devilsticks' as that just refers to the sticks, the equipment for the sport/art. (similar to calling the sport of hockey, 'hockey stick and skates'}
#
#
# Also the common usage is the plural, as in 'a set of sticks'... in the singular it refers to the 'center stick' or baton, or just stick. without the controlsticks/sidesticks/handsticks, it's just a baton.
# [[User:Pedant|Pedant]] 06:58, 2 Aug 2004 (UTC)
#
# MORE
# It was an error on my part to post the redirects before moving the page, it wasn't intentionalvandalism. I believe I have cleaned up any link messiness now. Thanks very much for your helpful suggestion and for noticing my error.
# [[User:Pedant|Pedant]] 20:30, 3 Aug 2004 (UTC)
#
# :Alright, well thanks for telling me. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 20:35, 3 Aug 2004 (UTC)
#
# == Some Russian to Myself ==
# &#1103; &#1087;&#1077;&#1096;&#1091; &#1087;&#1086; &#1088;&#1091;&#1089;&#1089;&#1082;&#1080;&#1081;! &#1087;&#1088;&#1072;&#1074;&#1077;&#1083;&#1085;&#1086; &#1103; &#1076;&#1077;&#1083;&#1086;&#1102;?
#
# I don't know if I spelled it right, therefore:
#
# "Ya peshoo <i>(short e)</i> po ruskee <i>(long u)</i>! Pravelno ya peshoo?"
#
# Means: I'm writing in russian? Am I writing correctly?
#
# [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 05:29, 6 Aug 2004 (UTC)
#
# : I've used `ispell -d russian' on your text; it caught 3 places and had correct suggestions for 2 of them (the 2nd and the last words).
# : Unfortunately, the rest had to be filled in by hand:
# ::&#1103; &#1087;&#1080;&#1096;&#1091; &#1087;&#1086;-&#1088;&#1091;&#1089;&#1089;&#1082;&#1080;! &#1087;&#1088;&#1072;&#1074;&#1080;&#1083;&#1100;&#1085;&#1086; &#1083;&#1080; &#1103; &#1076;&#1077;&#1083;&#1072;&#1102;?
# : HTH, [[User:BACbKA|BACbKA]] 14:57, 10 Aug 2004 (UTC)
#
# ::What is 'ispell'? Mac program? I have to find something similar for win32 [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 04:46, 11 Aug 2004 (UTC)
#
# == If you have some time? ==
#
# You were the first person to welcome me:
# ----
# What's up with all the orphaned redirects to a nonexistant article? Try [[Devil stick]] as opposed to [[Devil Stick]]. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 06:41, 2 Aug 2004 (UTC)
# ----
# I have gotten myself into a dispute over what I believe to be an important factual error.
#
# I edited a page, correcting a misstatment,
# I had several questions asked of me on that page's talk page, as my edits piqued some interest.
#
# The answers and questions became unwieldy enough and just enough off topic that I suggested moving the conversation.
#
# overnight, the page was reverted, to the former glaringly false state,
# saved by an anonymous user with 0 contributions.
#
# if you have time, I would really appreciate if you took a look at
# [[Sovereignty]] and it's talk page.
#
# I welcome any comments you might have, if you have the time to look it over...
# [[User:Pedant|Pedant]] 20:04, 6 Aug 2004 (UTC)
#
# :Uhm...okay, I'll take a look at it when I get a little more time. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 21:05, 6 Aug 2004 (UTC)
#
# ::thanks so much, sorry to presume on your time.  I'll be on a shoot for most of the next week, so no rush.  I neglected to mention it was a sysop that I tangled with, so maybe I'll be banned by the time I return...
# thanks again.
#
# == Sysop nomination ==
#
# I'm up for election to sysop status on [[Wikipedia:Requests for adminship]], and I think that you like me (not in ''that'' way, sicko ;-)!), so if you think that I would make a good admin, can you please vote for me? Thanks! [[User:Mike Storm|[[User:Mike Storm|Mike]]<font color=red>[[User talk:Mike Storm|&infin;]]</font>[[User:Mike Storm|Storm]]]] 00:28, 7 Aug 2004 (UTC)
# :I'd support you, but it's a bit too early, and i haven't seen enough of your work. Sorry, neutral. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 23:06, 7 Aug 2004 (UTC)
#
# == A quick Poll ==
#
# What monitor size and resolution do you use? Also what OS and Browser?(I use 17" and 1152x768x24, WinXP, Moz 1.7 BTW) I'm just wondering what the community uses. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 22:19, 2 Aug 2004 (UTC)
# * right now it's ''23" 1600x1200 Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.6) Gecko/20040614 Firefox/0.8'' The lowest I occasionally use is text 80x24 and lynx 2.8.5 [[User:BACbKA|BACbKA]] 22:38, 2 Aug 2004 (UTC)
# **Oh my god. A 23" monitor! 16x12! That would be heaven for me (particularly with a graphics card that supports that). [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 23:27, 2 Aug 2004 (UTC)
# ***I didn't intend to engage in comparative penilometry, just gave the honest specs :-) Right now I am surfing off a laptop, same browser/OS (the distro is Debian sarge BTW), but the resolution is 1024x768x24 at 15". Occn'ly I'm using Konqueror/3.2 (when I encounter a Firefox bug, mostly, or if I have a stupid site that is too much IE-optimized), but it is too heavy to use it as a default. Other than that, Konqueror is great. [[User:BACbKA|BACbKA]] 13:06, 3 Aug 2004 (UTC)
# * 19" 1600x1200x24, [[Gentoo Linux]], [[Mozilla Firefox]] with a browser window usually around 1000x1000. -- [[User:Wapcaplet|Wapcaplet]] 23:13, 2 Aug 2004 (UTC)
# * At work, 17" LCD monitor @ 1280x1024, Windows XP, Firefox; At home, 17" CRT monitor @ 1024x768, Windows 2000, Mozilla. Browser window always maximised. &mdash;[[User:Stormie|Stormie]] 23:32, Aug 2, 2004 (UTC)
# * Dual monitors of different sizes and resolutions. Browser windows stay near 750 px wide, which makes overly large fixed-width tables on Wikipedia jump out. -- [[User:Cyrius|Cyrius]]|[[User talk:Cyrius|&#9998;]] 23:40, 2 Aug 2004 (UTC)
# * 17" TFT monitor, 1280 x 1024, Windows 2000, MSIE. -- [[User:Arwel Parry|Arwel]] 00:57, 3 Aug 2004 (UTC)
# * 15" TFT (laptop), 1024x768, WinXP Pro and Firefox --[[User:AlexG|AlexG]] 01:48, 3 Aug 2004 (UTC)
# * 19" 1600x1200x24, a personal variant of [[Linux]], Firefox. -- [[User:Grunt|Grunt]] [[User_talk:Grunt|(talk)]] 01:56, 2004 Aug 3 (UTC)
# * 17" CRT 1280 x 1024, Firefox/Opera7 (and IE and Amaya when I feel like pain) all on XP.  Also 800x600 on laptop LCD, konqueror on linux (man, konqueror kicks ''ass'') Links and Lynx occasionally.-- [[User:Finlay McWalter|Finlay McWalter]] | [[User talk:Finlay McWalter | Talk]] 02:17, 3 Aug 2004 (UTC)
# * 15" TFT, 1400x1050, WinXP, MSIE. - [[User:UtherSRG|UtherSRG]] 02:31, 3 Aug 2004 (UTC)
# * All over the map, I routinely work from 4 different places. -- [[User:Jmabel|Jmabel]] 03:12, Aug 3, 2004 (UTC)
# * 15" CRT 800x600 24 bit, Win98Se, IE6 now but IE5.5 or maybe even IE5.0 shortly. [[User:Andrewa|Andrewa]] 04:36, 3 Aug 2004 (UTC)
# * Home: 15" LCD 1024&times;768, Gentoo, Firefox; Work: 17" CRT 1024&times;768, Win2k Pro, IE6. I don't edit much at work. --[[User:Rbrwr|rbrwr]][[User talk:Rbrwr|&circ;]] 06:23, 3 Aug 2004 (UTC)
# * 19" CRT, 1152x864, Opera 7 (maximised), XP [[User:Apwoolrich|Apwoolrich]] 06:32, 3 Aug 2004 (UTC)
# * 19" CRT, 1600x1200 (should probably go higher), IE6 in Windows 2000 or Firefox in Fedora Core 2, depending on mood... --[[User:Golbez|Golbez]] 06:50, 3 Aug 2004 (UTC)
# * 17" Flatscreen 128- x 1024, Opera 7, Windows XP. ALose use IE or Netscape if I'm fiddling with how things look, but I forget the versions.  [[User:Lyellin|Lyellin]] 08:21, Aug 3, 2004 (UTC)
# * @home: 19" CRT, 1280x1024, Opera 7 (latest build), WinXP SP2 P2 [[User:Anárion|Anárion]] 08:29, 3 Aug 2004 (UTC)
# * @work: 17" CRT, 1024x768, MSIE 6 (I have to alas :(), Win2000 SP4 [[User:Anárion|Anárion]] 08:29, 3 Aug 2004 (UTC)
# * 17" Flatscreen 1280x1024, Win XP Home, Opera 7.20 (seldom IE or Mozilla). [[User:Jao|Jao]] 08:57, Aug 3, 2004 (UTC)
# * 14" laptop 1024x768, Win2k Pro SP4, Opera 7.23 (w/ Firefox 0.8, Netscape 4.79 & 7.1, Mozilla 1.5, & [ugh!] MSIE 6.0sp1 for testing) &mdash; [[User:Jeffq|Jeff Q]] 09:42, 3 Aug 2004 (UTC)
# * 19" CRT 1600x1200, [[Gentoo linux]], [[Mozilla Firefox]]. [[User:Siroxo| ]]&mdash;[[User:Siroxo|<font color=#627562>siro</font>]][[User talk:Siroxo|<font color=#627562>''&chi;''</font>]][[User:Siroxo|<font color=#627562>o</font>]] 09:43, Aug 3, 2004 (UTC)
# * 15" CRT 1280x1024, [[Slackware Linux]], [[Mozilla Firefox]]. [[User:Johnleemk|Johnleemk]] | [[User talk:Johnleemk|Talk]] 10:40, 3 Aug 2004 (UTC)
# * 19" Viewsonic G90fPlus CRT (superb quality) at 1024px by 768px, Windows XP Home, IE Version 6 - [[User:Arpingstone|Adrian Pingstone]] 14:07, 3 Aug 2004 (UTC)
# * 35&nbsp;cm; 1024&times;768; [[Mac OS X]]; [[Safari (browser)|Safari]], [[Opera (browser)|Opera]], [[iCab]]. [[User:Gdr|Gdr]] 16:25, 2004 Aug 3 (UTC)
# * 17" CRT 1600x1200, [[Gentoo Linux]], Opera 7.53 [[User:aljandy|aljandy]] 17:56, 2004 Aug 3 (UTC)
# * 17" flatscreen, 1280x1024 (maximum, although I have it set at 1024x768), Windows XP Professional, Netscape 7.2 (or sometimes Mozilla). (I don't know the specifics of the Mac at work.) [[User:Adam Bishop|Adam Bishop]] 17:14, 3 Aug 2004 (UTC)
# * 15" monitor (unknown type) 1152x864, Windows XP, IE 6 |[[User:Rhymeless|Rhymeless]] 19:39, 3 Aug 2004 (UTC)
# *19" 1600x1200 with Firefox on my Linux computer, else 17" 1024x768 on my brother's Win XP computer with Firefox.
# *21" CRT 1024x768, though I used to run it at 800x600. FreeBSD 4.10 with Phoenixfox 0.9 as my main browser. [[User:Darrien|Darrien]] 21:33, 2004 Aug 4 (UTC)
#
# Around 85% of visits to WP are via IE. I expect this self-selecting poll will show a much lower number. What conclusions can we draw? [[User:Pcb21|Pcb21|]] [[User_talk:Pcb21|Pete]] 11:20, 3 Aug 2004 (UTC)
# :That where people have no choice of browser (work, library etc.) they will use IE, and otherwise they install a modern browser? [[User:Anárion|Anárion]] 13:22, 3 Aug 2004 (UTC)
# ::Not true. I'm a die-hard, build it yourself computer nerd. Or at least I was until I bought a laptop. (Ain't so easy to build something highly portable...) I've given up on trying to keep up with the latest and greatest hardware and software. When Netscape stopped coming out with updates way back when, I switched to MSIE, kicking and screaming all the way. When I bought my laptop with XP (finally an OS from MS that's reasonably worthy of being called an OS...) I continued with MSIE. I don't want to learn where all the tweak buttons are for yet another piece of software. I'm used to MSIE now. Can I do better? Sure. Will there be down-sides? Perhaps. Will they be small compared to the benefits? Probably. - [[User:UtherSRG|UtherSRG]] 19:02, 3 Aug 2004 (UTC)
# ::::You should try [[Firefox]]. At only 4.7MB and simple interface designed for the average user, its good to go, there is even a guide written about switching from IE[http://www.mozilla.org/products/firefox/switch.html]. It is also extendable, there is even Wikipedia specific extensions. Firefox is the browser of choice for all my family. So I recommend everybody who voted IE to try Firefox.   [[User:Krik|{{User:Krik/norm}}]] 21:58, 3 Aug 2004 (UTC)
# ::::Firefox is okay, Opera is a great browser also. A full internet suite in less than half the size of Firefox (less than a fifth if you want FF to be comparable and install Thunderbird + all those necessary extensions). As for IE being sufficient, I know people that were using Netscape 4 until 2003 so I can understand the reluctance to chance even though the browser is technically a generation or two behind... [[User:Anárion|Anárion]] 07:53, 4 Aug 2004 (UTC)
#
# Hi BACbKA. It was time to [[Wikipedia:Wikipedia maintenance|clean]] the [[Wikipedia:village pump|village pump]] so I've moved the results of your poll here. [[User:Angela|Angela]][[user talk:Angela|.]] 23:36, Aug 8, 2004 (UTC)
# :Looks like Angela didn't notice who was the poll originator. Here you go, it's yours! [[User:BACbKA|BACbKA]] 23:53, 8 Aug 2004 (UTC)
#
# ::Wow...I should do a dance. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 04:06, 9 Aug 2004 (UTC)
#
# ==New users==
# I just hang out on recent changes, watching for redlinked talk pages. It's usually pretty accurate. Best, [[User:Meelar|[[User:Meelar|Meelar]] [[User talk:Meelar|(talk)]]]] 19:17, 2004 Aug 9 (UTC)
#
# == Re: &#1082;&#1072;&#1082; &#1076;&#1077;&#1083;&#1072; ==
#
# &#1044;&#1077;&#1081;&#1089;&#1090;&#1074;&#1080;&#1090;&#1077;&#1083;&#1100;&#1085;&#1086;, &#1103; &#1075;&#1086;&#1074;&#1086;&#1088;&#1102; &#1087;&#1086;-&#1088;&#1091;&#1089;&#1089;&#1082;&#1080;. &#1044;&#1072;&#1078;&#1077; &#1095;&#1077;&#1089;&#1090;&#1085;&#1086; &#1087;&#1088;&#1080;&#1079;&#1085;&#1072;&#1083;&#1089;&#1103; &#1074; &#1101;&#1090;&#1086;&#1084; &#1074; &#1089;&#1087;&#1080;&#1089;&#1082;&#1072;&#1093; &#1074;&#1080;&#1082;&#1080;&#1087;&#1077;&#1076;&#1080;&#1089;&#1090;&#1086;&#1074; :-) [[User:BACbKA|BACbKA]] 19:28, 9 Aug 2004 (UTC)
#
# :Lol...good day then. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]]<font color="#333333"> [[User  talk:Ilyanep|(T&alpha;l&kappa;)</font>]] 19:30, 9 Aug 2004 (UTC)
# :BTW, I've finally listened to your .ogg from the Russian tongue-twisters (Carl &amp; Clara). Way cool! I am not sure I can do it that fast and clean. Posted another one there &mdash; inspired by you. [[User:BACbKA|BACbKA]] 19:52, 9 Aug 2004 (UTC)
# ::Huh? When did I post a Russian toungue-twister ogg? I only remember posting a 1-10 ogg. Might've been [[User:Ilya]]? [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 19:53, 9 Aug 2004 (UTC)
# :::Oops. Sorry, it was indeed the 1-10 there that I have seen your name around the Russian language audio. BTW, what's the easiest way to see the file upload history for an .ogg file (as opposed to an Image, for which there is the image page)? [[User:BACbKA|BACbKA]]
# ::::[[Media:Name.ogg]] It looks like an image page, but it's not :D [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 23:42, 9 Aug 2004 (UTC)
# :::::Thanks for the tip! It works. I now know that the .ogg in question was submitted by [[User:Timwi]]. [[User:BACbKA|BACbKA]] 08:04, 10 Aug 2004 (UTC)
#
# == fire triangle ==
#
# Cheers on the splendid editing job on [[fire triangle]].[[User:Pedant|Pedant]] 22:33, 9 Aug 2004 (UTC)
# :Thanks a lot...glad to help out...sorry I didn't have time to take a look at the soverignty article, I hope that was cleared up. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 23:13, 9 Aug 2004 (UTC)
# :::I think it has been, thanks. [[User:Pedant|Pedant]]
#
# == Another substub vote ==
#
# I just wanted to let people know that there's another vote on substubs going on in [[Template talk:Substub#Survey]]. I know that this is a second vote, however, apparently it was originally intended to be only a vote about whether to keep the ''template message'', but somehow evolved into a vote on the existence of substubs themselves. I know that you already voted in favor of substubs, so I wanted to get your support on this poll too. Thanks for your support! [[User:Mike Storm|[[User:Mike Storm|Mike]]<font color=red>[[User talk:Mike Storm|&infin;]]</font>[[User:Mike Storm|Storm]]]] 23:32, 9 Aug 2004 (UTC)
# :Apparantly, my support is becoming more of a burden, but I do believe in this, so let's go for it [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 23:41, 9 Aug 2004 (UTC)
#
# == B-Movie Bandit proxy range ==
# *Hello, my friend!  Thanks for all the support and love you've shown.  It makes me proud to be a part of this crazy site.
#
# Thanks to geektools.com, I was able to run the proxy for our friend, the B-Movie Bandit.  The vast majority are coming from here:
#
# *SBC Internet Services - Northeast SNET-CIDR002 (NET-64-252-0-0-1)
# *64.252.0.0 - 64.252.255.255
# *PPPoX Pool BRAS1 MRDNCT SBCIS-041403120525 (NET-64-252-160-0-1)
# *64.252.160.0 - 64.252.175.255
#
# Love you guys.  Really. - [[User:Lucky 6.9|Lucky 6.9]] 00:38, 10 Aug 2004 (UTC)
#
# == B-Movie Bandit, part two ==
#
# Two more entries just came in.  Same provider, different range:
#
# *SBC Internet Services - Northeast SBCIS-SNT-04 (NET-69-0-0-0-1)
# *69.0.0.0 - 69.0.127.255
# *PPPoX Pool BRAS1.mrdnct SBC069000036000030319 (NET-69-0-36-0-1)
# *69.0.36.0 - 69.0.39.255
#
# What a day... - [[User:Lucky 6.9|Lucky 6.9]] 03:03, 10 Aug 2004 (UTC)
#
# == Thank you for your help to me. ==
#
# Nice to meet you. Ochin Preyatnaba! (is it right pronaunciation? If not, I am sorry. I have been in Kazahstan for 3 month and just learn Lusky Yazik zu zu.) For your kind help, I would learn more about WikiPedia and appreciated for your alturistic support. Bye! Dasbidanya! -- [[User:RomanPark|RomanPark]]
# :Thanks, well if you ever need help, feel free to leave a note here. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 15:52, 12 Aug 2004 (UTC)
#
# == Shallot and Joy ==
#
# [[User:Joy]] is now the sysop, and [[User:Shallot]] is not because the latter is deprecated as an account. Actually, Angela did the desysop on Shallot. Cheers! [[User:Cecropia|Cecropia]] | [[User talk:Cecropia|Talk]] 18:05, 12 Aug 2004 (UTC)
# :Okay, just checking [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 18:42, 12 Aug 2004 (UTC)
#
# == Geek Code ==
# Cool, personally I used [http://www.joereiss.net/geek/ungeek.html this] to decode yours because I'm just too lazy to do it by hand... :). [[User:Mbecker|<nowiki></nowiki>]] &mdash; [[User:Mbecker|<font color="007700">&#12510;&#12452;&#12465;&#12523;</font>]] [[User talk:Mbecker|<font color="ff9900">&#8362;</font>]] 19:44, Aug 12, 2004 (UTC)
# :Yeah, that's what I use. [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 19:46, 12 Aug 2004 (UTC)
# ::He, mine's a little old, I should update it... [[User:Mbecker|<nowiki></nowiki>]] &mdash; [[User:Mbecker|<font color="007700">&#12510;&#12452;&#12465;&#12523;</font>]] [[User talk:Mbecker|<font color="ff9900">&#8362;</font>]] 19:47, Aug 12, 2004 (UTC)
# :::lol...go right ahead :D. The code itself is a bit old tho (1995) [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 19:49, 12 Aug 2004 (UTC)
# I updated my code, not because the code changed, but because I changed... [[User:Mbecker|<nowiki></nowiki>]] &mdash; [[User:Mbecker|<font color="007700">&#12510;&#12452;&#12465;&#12523;</font>]] [[User talk:Mbecker|<font color="ff9900">&#8362;</font>]] 19:58, Aug 19, 2004 (UTC)
# :Yeah, I understand. [[User:Ilyanep|{{User:Ilyanep/sig}}]] 19:59, 19 Aug 2004 (UTC)
#
# == steward ==
#
# I replied to your
# [http://meta.wikimedia.org/wiki/Talk:Stewards#becoming_a_steward.3F steward-question] :-) [[User:Fantasy|Fantasy]] 12:11, 13 Aug 2004 (UTC)
# :Jeez finally. Lol, I didn't care if it was even a negative reply (oops...did I say that out loud :P). Anyways, thanks :) [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 16:47, 13 Aug 2004 (UTC)
#
# == Your vote needed at [[George_W._Bush]] ==
#
# Please go [http://en.wikipedia.org/wiki/Talk:George_W._Bush#Bush.27s_purchase_of_Texas_Rangers here], ASAP and vote.
#
# [[User:Rex071404|Rex071404]] 07:11, 16 Aug 2004 (UTC)
#
# == New Bush vote now under way - please vote ==
#
# Here [http://en.wikipedia.org/wiki/Talk:George_W._Bush#Texas_Rangers_-_Consensus_building_attempt:_Please_vote_V.2_-_08.16.2004]
#
# [[User:Rex071404|Rex071404]] 15:57, 16 Aug 2004 (UTC)
#
# == DOWN WITH AOL ==
#
# This is the final straw. [[User:Ilyanep/DWAOL]] [[User:Ilyanep| ]]&mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)</font>]] 21:02, 17 Aug 2004 (UTC)
#
# == changing the color in your signature ==
#
# How do you do it? I have looked in all the editing and style guides. I have used Google and just about every other tool at my disposal. HTML doesn't seem to work, at least the span tag doesn't. Others I think use the font tag but it is deprecated.
#
# --[[User:Sunborn|The Sunborn]] 03:28, 20 Aug 2004 (UTC)
#
# :Oh the accursed span tag. I personally use the font tag, and it works fine for me. What do you mean it's deprecated? Never heard such a thing. [[User:Ilyanep|{{User:Ilyanep/sig}}]] 15:31, 20 Aug 2004 (UTC)
#
# ::The font tag is [http://www.w3.org/TR/REC-html40/index/elements.html certainly deprecated], i.e. it should not be used. The span and div tags should be used instead with CSS. I also notice that my signature is <nowiki>[[User:Sunborn|The Sunborn]]</nowiki> an yours is <nowiki>[[User:Ilyanep|{{User:Ilyanep/sig}}]]</nowiki>.  --[[User:Sunborn|The Sunborn]] 19:58, 20 Aug 2004 (UTC)
#
# :::Well, so that my sig didn't take up like 3 lines, I use <nowiki>{{User:Ilyanep/sig}}</nowiki> to make the markup a lot better looking. I personally don't really care if it's deprecated, as long as it works :P [[User:Ilyanep|{{User:Ilyanep/sig}}]] 20:39, 20 Aug 2004 (UTC)
#
# ::::Thanks, --[[User:Sunborn| ]]</b>metta, <b>[[User_talk:Sunborn| <font color="#FF0000">T</font><font color="#000000">h</font><font color="#FF0000">e</font><font color="#000000"> S</font><font color="#FF0000">u</font><font color="#000000">n</font><font color="#FF0000">b</font><font color="black">o</font><font color="#FF0000">r</font><font color="black">n</font> </b>]] 22:47, 20 Aug 2004 (UTC)
#
# :::::<Strike>Glad to be of help...but may I suggest also using a template? Make a template such as <nowiki>{{User:Sunborn/sig}}</nowiki> and paste <nowiki>[[User_talk:Sunborn| <font color="#FF0000">T</font><font color="#000000">h</font><font color="#FF0000">e</font><font color="#000000"> S</font><font color="#FF0000">u</font><font color="#000000">n</font><font color="#FF0000">b</font><font color="black">o</font><font color="#FF0000">r</font><font color="black">n</font> </b>]]</nowiki> into there then in the preferences window put <nowiki>{{User:Sunborn/sig}}</nowiki> as your signature. It makes the wikimarkup a lot simpler to look at.</strike> Stike that...after a certain amount of this template on a page, the template breaks for some reason... [[User:Ilyanep|{{User:Ilyanep/sig}}]] 00:44, 21 Aug 2004 (UTC)
#
# ::::::WTF are you talking about? It works fine for me, and I have a major amount of stuff in the template source. Your way works great. Thanks again. --[[User:Sunborn|{{User:Sunborn/sig}}]] 14:34, 22 Aug 2004 (UTC)
#
# :::::::I don't know, just once on the Village pump it didn't work for some reason :( [[User:Ilyanep|Ilyanep]] &mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;]][[Special:Contributions/Ilyanep|<font color="#333333">, c&omicron;&eta;tr&iota;bs)]] 15:26, 22 Aug 2004 (UTC)
# :::::: Any template inevitably breaks the 6th (i think, rather than 5th) time it is used on the same page.  It's an important feature, discussed in more than one place; one of my recent edits near the top of [[Wikipedia talk:Votes for deletion]] is one of them, w/ someone else's & a link to details in the same section. --[[User:Jerzy|Jerzy]][[User talk:Jerzy|(t)]] 21:29, 2004 Aug 23 (UTC)
#
# == Riga Int'll Airport ==
#
# No problem. :) [[User:Neutrality|[[User:Neutrality|<b>Neutrality</b>]] ([[User talk:Neutrality|talk]])]] 15:46, 22 Aug 2004 (UTC)
#
#
#
#
#
# [[User talk:Ilyanep|Ilyanep's Talk]] , [[User talk:Ilyanep/Talk Archive 1|Archive 1]] , [[User talk:Ilyanep/Talk Archive 2|Archive 2]] , [[User talk:Ilyanep/Talk Archive 3|Archive 3]]
#
#
#
#
#
# {{test}} -- [[User:Infrogmation|Infrogmation]] 05:08, 24 Aug 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# ==[[Wikipedia:Welcome, newcomers|Welcome]] to the [[Wikipedia]]==
# Here are some links I thought useful:
#
# *[[Wikipedia:Tutorial]]
# *[[Wikipedia:Help desk]]
# *[[M:Foundation issues]]
# *[[Wikipedia:Policy Library]]
# *[[Wikipedia:Utilities]]
# *[[Wikipedia:Cite your sources]]
# *[[Wikipedia:Verifiability]]
# *[[Wikipedia:Wikiquette]]
# *[[Wikipedia:Civility]]
# *[[Wikipedia:Conflict resolution]]
# *[[Wikipedia:Neutral point of view]]
# *[[Wikipedia:Pages needing attention]]
# *[[Wikipedia:Peer review]]
# *[[Wikipedia:Bad jokes and other deleted nonsense]]
# *[[Wikipedia:Brilliant prose]]
# *[[Wikipedia:List of images]]
# *[[Wikipedia:Boilerplate text]]
# *[[Wikipedia:Current polls]]
# *[[Wikipedia:Mailing lists]]
# *[[Wikipedia:IRC channel]]
#
# Feel free to contact me personally with any questions you might have. The [[Wikipedia:Village pump]] is also a good place to go for quick answers to general questions. You can sign your name by typing 4 tildes, like this: <nowiki>~~~~</nowiki>.
#
# [[Be Bold]]!
#
# [[User:Sam Spade|Sam]] [[http://en.wikipedia.org/w/wiki.phtml?title=User_talk:Sam_Spade&action=edit&section=new '''Spade''']] 05:21, 24 Aug 2004 (UTC)
#
#
#
#
#
# Thanks for experimenting with Wikipedia. Your test worked, and has now been removed. Please use [[Wikipedia:Sandbox]] for any other tests you want to do, since testing material in articles will normally be removed quickly. Please see the [[Wikipedia:Welcome, newcomers|welcome page]] if you would like to learn more about contributing to our encyclopedia. Thanks. [[User:Ilyanep| ]] &mdash; [[User:Ilyanep|<font color="grey">Il&gamma;&alpha;&eta;&epsilon;&rho;</font>]] [[User  talk:Ilyanep|<font color="#333333">(T&alpha;l&kappa;)]] 05:28, 24 Aug 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# Please don't post newspaper articles to Wikipedia.  If you want to write an article about [[Lon Horiuchi]], please do so in your own words.  [[User:RickK|Rick]][[User talk:RickK|K]] 05:55, Aug 24, 2004 (UTC)
#
#
#
#
#
# We;ve had this discussion about the Clitoris article before.  You can't arbitrarily come in and revert that picture.  You have already lost the discussion.  Leave it.  [[User:RickK|Rick]][[User talk:RickK|K]] 06:12, Aug 24, 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# nan
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# Please don't post spam on Wikipedia.  [[User:RickK|Rick]][[User talk:RickK|K]] 06:58, Aug 24, 2004 (UTC)
#
#
#
#
#
# #REDIRECT [[The super online game-Legend Arena]]
#
#
#
#
#
#
# nan
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{test}} [[User:Andris|Andris]] 09:21, Aug 24, 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# Please do not create articles that are not serious encyclopedic entries. Doing so is considered vandalism, and hinders the progress of Wikipedia while making work for others who have to clean it up. [[User:Livajo|Livajo]] 10:13, 24 Aug 2004 (UTC)
#
#
#
#
#
# <hr><hr><hr><hr><hr>
#
#
#
#
#
# nan
#
#
#
#
#
# Please stop vandalizing Wikipedia pages. It is futile since they just get quickly changed back and it creates a hassle for others. Livajo 11:13, 24 Aug 2004 (UTC)
#
#
#
#
#
# == Redirects ==
#
# Please see [[Wikipedia:Redirect]] for information on how redirects are used.  I see no reason why [[D. T. Suzuki]] should be redirected, so I'm restoring it all, and removing it from [[WP:VFD]]. [[User:Duncharris|Dunc_Harris]]|[[User talk:duncharris|&#9786;]] 11:45, 24 Aug 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# {{test}} [[User:Livajo|Livajo]] 12:38, 24 Aug 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# [[Socialism]] is a beauracracy that collapses under its own weight.  It lacks fundamental checks and balances to exist in a natural political environment.  People who advocate socialism are usually intellectually lazy to find a way to create something for a world that requires people to be productive members of society.
# It is inaccurately refered to as an ideology because it is perpatrated as an ideology by the egomaniacs who want to be on control.
# Before some of you start blasting me for my strong point of view on the matter save it for another time.  I had the misfortune of knowing that sort of history firsthand.  Socialism was an ancient method of governing a population before it even started.  [[User:slavik914]]
#
#
#
#
#
# ===Welcome to Wikipedia===
# Hello and welcome to Wikipedia! We're glad to have you as a contributor; however, we have a policy against users writing about themselves and their own projects (this is generally considered vanity). It is also generally agreed upon that article should never directly link to a user's page; if a person mentioned in an article is notable enough, they should get an article for themselves, no matter if they also have a user page (in this case, however, I'd recommend against creating an article about yourself since that would also be considered vanity :).
#
# Again, welcome, we're looking forward to your future contributions!
# -- [[User:Ferkelparade|Ferkelparade]] [[User_talk:Ferkelparade|&pi;]] 13:32, 24 Aug 2004 (UTC)
#
#
#
#
#
#
# I'm really happy after coming to know the job WIKIPEDIA is doing in the global village. Well done. I hope one day will come when 'netizens' will bother nowhere else for the scattered knowledge on the web and will get everything under the umbrella of WIKIPEDIA. The Pakistani people are taking very interest in your job and every day a lot more volunteers are joining your team. Chow.
#
#
#
#
#
# Thank you for correcting the wavelength in [[MERLIN]].<br>
# [[User:Bobblewik|Bobblewik]]&nbsp;&nbsp;[[User talk:Bobblewik|(talk)]] 14:41, 24 Aug 2004 (UTC)
#
#
#
#
#
# Is there any middle ground between Communityism and encylopedianism? [[User:Neutrality|[[User:Neutrality|<b>Neutrality</b>]] ([[User talk:Neutrality|talk]])]] 14:54, 24 Aug 2004 (UTC)
#
#
#
#
#
# Hi there. [[Wikipedia:Welcome, newcomers|Welcome]] to Wikipedia! Thanks for your contributions on Hungarian counties.  Looks like good stuff.  I hope you like it here and stick around. If you want, you can drop us a note at [[Wikipedia:New user log]] to introduce yourself.
#
# Before you start doing a lot of editing, you'll want to take the [[Wikipedia:Tutorial|Tutorial]]. It gives all the basic info you'll need as you start contributing.
#
# You can sign your name on talk pages by using <nowiki>" ~~~ " for your username and " ~~~~ " for your username and a timestamp.</nowiki>
#
# If you have any other questions about the project then check out [[Wikipedia:Help]] or add a question to the [[Wikipedia:Help desk|Help desk]]. You can also drop me a question on my [[User Talk:Isomorphic|talk page]].
#
# Happy editing, [[User:Isomorphic|Isomorphic]] 15:28, 24 Aug 2004 (UTC)
#
#
#
#
#
# Please do not vandalize the pages on Wikipedia. It just creates work for others to clean up (which is done pretty quickly, making the vandalism essentially futile). [[User:Livajo|Livajo]] 15:46, 24 Aug 2004 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# {{Welcome}} - [[User:Lucky 6.9|Lucky 6.9]] 15:49, 24 Aug 2004 (UTC)
#
# Also, please take a look at the [[Wikipedia:Manual of Style]].  Thanks!
#
#
#
#
#
# '''Warning:''' ''[[Wikipedia:Boilerplate_text|Boilerplate text follows]].''
#
# Hello there! [[Wikipedia:Welcome, newcomers|Welcome]] to Wikipedia! We've noticed that you've been making some great additions to the Wikipedia and we ''really'' appreciate it. Why not [[Special:Userlogin|create an account]] and stay awhile? The Wikipedia can use as many quality members as possible. If you ever need editing help visit [[Wikipedia:How does one edit a page]] and experiment at [[Wikipedia:Sandbox]]. If you need pointers on how we title pages visit [[Wikipedia:Naming conventions]]. If you have any other questions about the project then check out [[Wikipedia:Help]] or add a question to the [[wikipedia:Village pump|Village pump]]. Hope to see you around for a long time to come! -- [[User:Grunt|Grunt]] [[User_talk:Grunt|(talk)]] 16:01, 2004 Aug 24 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# Please do not add commercial links to Wikipedia. [[Wikipedia:Wikipedia is not|Wikipedia is not]] a vehicle for advertising or a mere collection of external links. See the [[Wikipedia:Welcome, newcomers|welcome page]] if you would like to learn more about contributing to our encyclopedia. Thanks. -- [[User:Grunt|Grunt]] [[User_talk:Grunt|(talk)]] 16:02, 2004 Aug 24 (UTC)
#
#
#
#
#
# Hi, "Pretzelpaws{{Infrog welcome}}. Cheers, -- [[User:Infrogmation|Infrogmation]] 16:10, 24 Aug 2004 (UTC)
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{test}} -- [[User:Infrogmation|Infrogmation]] 16:14, 24 Aug 2004 (UTC)
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# Hi there,
# Thanks for the TLC picture, but please upload a copy of http://www.tlc.qld.edu.au/assets/launcher/launch_r7_c2.gif instead--the picture you used looked like a screenshot and was of pretty poor quality. --[[User:Lukobe|Lukobe]] 16:58, 24 Aug 2004 (UTC)
#
#
#
#
#
# Chat sniffs the kitty
#
#
#
#
#
# Who is Schmidhuber? Why are they important? Please answer on [[Talk:European_Union_Olympic_medals_count_for_2004]]. Thanks. --[[User:Kjd|kjd]] 17:22, 24 Aug 2004 (UTC)
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# Hi, "Czrisher{{Infrog welcome}} -- [[User:Infrogmation|Infrogmation]] 17:39, 24 Aug 2004 (UTC)
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# Thanks for experimenting with Wikipedia. Your test worked, and has now been removed. Please use [[Wikipedia:Sandbox]] for any other tests you want to do, since testing material in articles will normally be removed quickly. Please see the [[Wikipedia:Welcome, newcomers|welcome page]] if you would like to learn more about contributing to our encyclopedia. Thanks. -- [[User:Grunt|Grunt]] [[User_talk:Grunt|(talk)]] 17:50, 2004 Aug 24 (UTC)
#
#
#
#
#
# nan
#
#
#
#
#
# ==[[Wikipedia:Welcome, newcomers|Welcome]] to the [[Wikipedia]]==
# ...
#
# :Which user are you talking about? There doesn't seem to be a [[he:&#1502;&#1513;&#1514;&#1502;&#1513;:David Shay]]. Also, what is your user name on the Hebrew Wikipedia? [[User:Angela|Angela]][[user talk:Angela|.]] 22:04, Aug 18, 2004 (UTC)
#
# I don't have a username in the Hebrew Wiki because I always blocked by the same user (&#1490;&#1497;&#1500;&#1490;&#1502;&#1513;).
# I want to open a alternative Wikipedia in Heberw: I've got 2 ideas.
# 1. I can use the Yidesh wikipedia (the is no articles in it - this is so old language that doesn't really spoken. The is no man under 70 that speaks that language.
# 2. I can open a new wikipedia... I can use the Hebrew interface [http://meta.wikimedia.org/w/wiki.phtml?title=LanguageNH.php&action=edit]
#
# :It would be a lot easier for people to communicate with you if you created a username. I don't think you should try forking the Hebrew Wikipedia. This dispute can be solved, and I suggest you talk with one of the admins there about it. Can you give me any examples of what this user has done and why you think he is being a dictator please? [[User:Angela|Angela]][[user talk:Angela|.]] 15:48, Aug 19, 2004 (UTC)
#
# One good example is the articles about politician or about the Israel army - if you worte something negative but true about this articles you will be blocked.
# Another exemple is article that articles that exist in the English wikipedia (and in more languages) deleted when they translated to Hebrew because one of them didn't find it important. This happaned with articles about Porn star (there was no "dirty words" or pornography in the pages - and I even didn't translated some part from the English Wikipedia that might be cosidered "dirty") that where translated as they are to Hebrew. They delete all the article without making a vote. Most of the Hebrew user wanted to keep the articles (the write about it) but some sysops decided to delete it. and everytime I tried to talk about it or to show my opnion they blocked me.
#
# I think that I don't have another choice but tring open a New Hebrew Wikipedia.
#
# :Do you have a [[Wikipedia:votes for deletion|votes for deletion]] page on the Hebrew Wikipedia where this was discussed? Or have you tried bringing it up on [[he:&#1493;&#1497;&#1511;&#1497;&#1508;&#1491;&#1497;&#1492;:&#1502;&#1494;%D7%25A0&#1493;&#1503;|&#1502;&#1494;&#1504;&#1493;&#1503;]]? Also, have you tried talking to [[he:&#1502;&#1513;&#1514;&#1502;&#1513;:&#1490;&#1497;&#1500;&#1490;&#1502;&#1513;|&#1490;&#1497;&#1500;&#1490;&#1502;&#1513;]] and explaining to him what the problem is? I'm sure this can be worked out by discussion with users there rather than trying to start a new site for it. [[User:Angela|Angela]][[user talk:Angela|.]] 16:37, Aug 19, 2004 (UTC)
#
# I worte about it in the &#1502;&#1494;&#1504;&#1493;&#1503; but &#1490;&#1497;&#1500;&#1490;&#1502;&#1513; deleted the things that I worte (He kept only his point of view). He deleted it only because he don't like the subjects of the articles.
#
# :Ok, but there are 17 other admins there. I'm sure they can't all be as bad as you think &#1490;&#1497;&#1500;&#1490;&#1502;&#1513; is. Just approach people calmly without accusing them of being dictators or making other personal attacks, and I'm sure there are reasonable people there who will be able to explain to you why your pages were deleted, or help you to get them undeleted if &#1490;&#1497;&#1500;&#1490;&#1502;&#1513; really was abusing his position. People might take you more seriously if you create a username there too. [[User:Angela|Angela]][[user talk:Angela|.]] 17:06, Aug 19, 2004 (UTC)
#
# I have created some usenames but &#1490;&#1497;&#1500;&#1490;&#1502;&#1513; block me. My page were translated carefully from the English Wikipedia so there is no reason to delete them. Can you let me be a sysop in the Heberew Wikipedia for protecting those page form deletion?
#
# :Sorry, I can't make you a sysop. That is something the users of the Hebrew Wikipedia need to decide. What reason are they giving for blocking you? Is there some policy you are breaking? [[User:Angela|Angela]][[user talk:Angela|.]] 21:03, Aug 19, 2004 (UTC)
#
# They are blocking me because I put back my articles. All the sysops became sysop by one user in the Hebrew Wikipedia. I think you have the ability to set me as a sysop. (They delete everything I worte include talk pages and &#1502;&#1494;&#1504;&#1493;&#1503; - so I can't even tell the others my point of view).
# If you cannot I am asking you to let me open a new Wikipedia.
#
# :I think you need to respect the results of the vote at [[he:&#1493;&#1497;&#1511;&#1497;&#1508;&#1491;&#1497;&#1492;:&#1502;&#1494;&#1504;&#1493;&#1503;/&#1508;&#1493;&#1512;&#1504;&#1493;&#1490;&#1512;&#1508;&#1497;&#1492;]]. Have you tried to discuss it with the other users who voted to keep the articles? [[User:Angela|Angela]][[user talk:Angela|.]] 21:50, Aug 19, 2004 (UTC)
#
# The results are a complete bullshit (sorry for the language). The manipulated the results - They wrote that people who wants to keep as they want to delete it. I tried to make a new poll that will be honest (Every user will vote by himself - another users will not decide for him). Their respone was to delete it and to block me.  They don't let me write there and show my point of view. (look at the page history). PS: They had deleted my articles many times before they made the "honest" poll.
#
# *How about you try to gain more trust over there by focusing on some different articles. You should consider stopping trying to recreate pages that were already deleted, as they will see this as vandalism. Instead, just find something else to write about, and then later on you can start a sensible discussion of this issue once the arguments have died down. [[User:Angela|Angela]][[user talk:Angela|.]] 22:12, Aug 19, 2004 (UTC)
#
# The reason I recreated the page was about pure ideology, freedom of speech, and the future of the Hebrew Wikipedia. It was about keeping Wikipedia FREE as it supposed to be. Today it is Porn stars. Tomorrow who knows?
#
# How can I create other articles when I don't know if they would keep them?
#
#
# Hi, I can prove that i m not a internet troll.
# list of my contributions that i was the one who write them:
# i worte about 15 articles:
#
# *. Subliminal Message - &#1502;&#1505;&#1512; &#1514;&#1514;-&#1505;&#1497;&#1508;&#1497;
#
# *. Homer Simpson - &#1492;&#1493;&#1502;&#1512; &#1505;&#1497;&#1502;&#1508;&#1505;&#1493;&#1503;
#
# *. Indymedia - &#1488;&#1497;&#1504;&#1491;&#1497;&#1502;&#1491;&#1497;&#1492;
#
# i can prove that i worte them: if u look at the password of the user who wrote tham (in the begining) you see it's all the same.
#
# if u don't want me delete my contributions.
#
# i am leaving wikipedia.
#
# :Ok, well stick with one user name, and try to stick to articles that people have not already voted against. Since there were 10 people voting to delete your pages, it is clearly not an issue that one user is being a dictator over this. Sorry I can't help, but it is really up to you and the community on the Hebrew Wikipedia to work this out. I can't force them to keep your articles, and nor would I want to go against the consensus that has formed for getting rid of them. If these articles are important to you, you can always [[Wikibooks:Wiki Science:How to start a Wiki|start your own wiki]], but this can't be hosted as part of Wikimedia. [[User:Angela|Angela]][[user talk:Angela|.]] 17:31, Aug 20, 2004 (UTC)
#
# ==Hebrew (Gilgamesh)==
#
# hi,<BR>
# i am the administrator &#1490;&#1497;&#1500;&#1490;&#1502;&#1513; i banned the user since he was vandalising the hebrew wikipedia. he wanted to add some pornographical articals which we don't want to have in he.wiki. we voted against it in our village pump and the vote was 10 to 4 in favor of deleting those articles. David Shay is a very respectfull member of our wiki. there is no other administrator, who feels he is a dictator, furthermore we are delighted of his work.
#
# this particular user opened at least 10 or 15 differnt usernames and rewrote his articles at least 100 times. this user is an Internet troll and we complained to his internet provider. if he will persist in his behavior we will involve the police. as for now, after the vote he is not alowed to write any article in whatever subject in he.wiki again.
#
# his claims about nitionalistic point of view in issues of israely security and pokitics is wrong. you can translate the article to inglish via google and see for yourself. if it doesn't work, i hope u have some administrators who speek hebrew and can read the discussion in the village pump and in discussion pages of the requsted articles
#
# any way any complaint of an internet troll should be regarded as disturbance to peace and shoud not be tolerated.
#
# I have a username in en. wiki and u can reach me here.
#
# best regards,<BR>
# [[User:Gilgamesh he|Gilgamesh he]] 22:40, 19 Aug 2004 (UTC)
#
# thank you for your answer i hope he will not return and we wont enjoy the questionable pleasure of his company [[User:Gilgamesh he|Gilgamesh he]] 22:55, 19 Aug 2004 (UTC)
#
# ==Hebrew (Avihu)==
#
# Hi, Angela,
#
# My name is Avihu and I am one of the 18 administrators of the Hebrew Wikipedia .I am very sorry to see our dirty laundry washed in public. I just want to add a few facts to those that were written by Gilgamesh:
# *Contrary to what the anonymous user wrote to you, David Shay who is the Hebrew Wikipedia’s bureaucrat is currently on vacation in London and was not involved with the conflict about Pornography that raged in the Hebrew Wikipedia for the last two days.
# *The anonymous user used foul language when he was questioned about the validity of the articles he created. I am not going to repeat what he said, but he insulted anyone, administrator or user which dared to ask for softening his Pornography articles.
# What we need is a way to block the user’s IP address even if he is a registered user, because some of us wasted lot of time and energy blocking the phony user names he created repeatedly, deleting his articles and discussing the merits of pornography on the village pump instead of writing articles.
#
# Regards, [http://he.wikipedia.org/wiki/&#1513;&#1497;&#1495;&#1514;_&#1502;&#1513;&#1514;&#1502;&#1513;:&#1488;&#1489;&#1497;&#1492;&#1493; My user talk page on the hebrew wikipedia] [[User:Avihu|Avihu]] 09:21, 20 Aug 2004 (UTC)
#
# :Hi Angela,
#
# :To your first question: as far as I know he only used user name during the last couple of days so I do not know his IP. Maybe there is a tool that can tell me what is the current IP address of a user, which is signed on.
#
# :Your response is very important and remaining question is where can I read about all the tools you mentioned (blocking range of addresses, preventing new users from creating articles).
#
# : Regards, [http://he.wikipedia.org/wiki/&#1513;&#1497;&#1495;&#1514;_&#1502;&#1513;&#1514;&#1502;&#1513;:&#1488;&#1489;&#1497;&#1492;&#1493; My user talk page on the hebrew wikipedia] [[User:Avihu|Avihu]] 11:49, 20 Aug 2004 (UTC)
#
# ::Hi Angela,
#
# ::I understand.
#
# ::Thanks
# ::[[User:Avihu|Avihu]] 12:26, 20 Aug 2004 (UTC)
#
# == Sysop Accountability Policy ==
#
# Good morning, Angela.  On my Talk page, you asked about the archiving and closure of Wikipedia:Sysop Accountability Policy.  For consistency of the thread, I answered there.  The short version - I interpreted the consensus as "keep in BJAODN".  Never having paid much attention to that page, I tried to find a queue where someone who does use BJAODN could take care of it. It was a temporary fix that I was hoping to improve on. If you have a better answer or want to overwrite my "closure", I would sure appreciate it. [[User:Rossami|Rossami]] 11:22, 19 Aug 2004 (UTC)
#
# : Thank you. [[User:Rossami|Rossami]]
#
# == Luzmila Carpio page ==
#
# Hi Angela,
#
# I'm quite new to Wikipedia. I wanted to add a page to Wikipedia for which I'm the copyrights holder.
#
# However this page has been listed in the Copyright problems page, my fault, I copy-pasted my document without removing unrelated information which might have caused the trouble.
#
# [[Talk:Luzmila carpio|The talk related to that is here]].
#
# Thank you for your assistance!
#
# Joel
#
#
# == [[User:Angela/London|London]] ==
#
# hey - murray here - guess you found the ntk link :)  hope that is all good.  I'm not sure how the evening talk will shape up - may just be a small crowd in a pub, may be bigger.  Should be all good tho.
#
# The day stuff looks like the order may jiggle around a bit, but the topics are the same (if thats all cool?).  Got 40 people + a waiting list for the main talk.  If we can get a bigger room, there may be more.  And somewhere we're hoping to get a few minutes with some of the higher ups.
#
# Are you coming along too, or are you just helping with notes?  Looking forward to this!
#
# :Replied by email. [[User:Angela|Angela]][[user talk:Angela|.]] 21:32, Aug 20, 2004 (UTC)
# : ta. guess you emailed work : won't get that until monday.  have a lovely weekend :)
#
# ::Ah, it's Friday night already. Sorry, I lost track of my timezone a while ago. :) I've emailed you at gmail now. [[User:Angela|Angela]][[user talk:Angela|.]] 21:51, Aug 20, 2004 (UTC)
#
# == Picture ==
#
# Thanks for the kind comments on [[:image:Korea_gyeongbokgung.jpg]]. Well, it ''is'' one of my favourites. You can now nominate it ;-) [[User:Kokiri|Kokiri]] 22:41, 20 Aug 2004 (UTC)
#
# ==Thai Wikipedia==
#
# Thanx in a million for your help. I can handle vandalism on the Dutch wiki (I am a moderator there) but not on the Thai wiki. I do live in Thailand and can read a littlebit of Thai. I will try and restore everything in the correct versions later. [[User:Waerth|Waerth]] 17:59, 21 Aug 2004 (UTC)
# :I just saw that 203.145.13.22 also vandalised your userpage. I will keep an eye on the Dutch wiki and all the other ones I have a userpage ... [[User:Waerth|Waerth]] 18:08, 21 Aug 2004 (UTC)
#
# ::Hmmm. I guess it would be helpful if blocks carried across wikis. [[User:Angela|Angela]][[user talk:Angela|.]] 18:12, Aug 21, 2004 (UTC)
#
# :::Not always. Just last week I have gotten an internetconnection at home. It took me 5 years to get one (do not ask me ... I just refuse to pay bribes). Before that I worked from an internetcafe around the corner. One day somebody else vandalized the English wikipedia from that cafe and I found the ip address blocked, I couldn't even login anymore. Luckily enough I could still edit on the Dutch wiki so I could tell Andre Engels. This IP address is not from that internetcafe, but is probably from Thailand. What would be usefull is having some kind of warning page at meta where the moderators could look for crosswiki vandalism. [[User:Waerth|Waerth]] 18:29, 21 Aug 2004 (UTC)
#
# ::::Having a cross-wiki [[Special:Contributions]] page might be a better alternative then. [[User:Angela|Angela]][[user talk:Angela|.]]
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# What is the source of the pictures you have been uploading? Are they in the public domain? - [[User:SimonP|SimonP]] 18:33, Aug 24, 2004 (UTC)
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# nan
#
#
#
#
#
# nan
#
#
#
#
#
# Hi, welcome to Wikipedia.  Unfortunately, I had to revert the edits you made to the [[Vanessa Marcil]] article because one user ahead of you had added a copyright violation which can't stay on Wikipedia.  Please go back to the article and add new information.  Thanks.  [[User:RickK|Rick]][[User talk:RickK|K]] 18:39, Aug 24, 2004 (UTC)
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# {{test}}
#
#
#
#
#
# nan
#
#
#
#
#
# nan
#
#
#
#
#
# nan
#
#
#
#
#
# {{User:Meelar/wel}}
#
#
#
#
#
# {{test}} -- [[User:Infrogmation|Infrogmation]] 18:50, 24 Aug 2004 (UTC)
#
#
#
#
#
# nan
