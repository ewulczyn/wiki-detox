# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext autotime

import warnings
warnings.filterwarnings('ignore')

from ngram import *
from baselines import *
from error_analysis import *

# %%
task = 'aggression_score'
# Out:
# time: 2.01 ms

# %% [markdown]
# ### Load Annotated Data

# %%
d_b, d_r = load_cf_data()
# Out:
# time: 18 s

# %%
l_b = plurality(d_b[task].dropna())
l_r = plurality(d_r[task].dropna())
# Out:
# time: 25.8 s

# %%
def mapl(l):
    if l < 0:
        return 1
    else:
        return 0
    
l_b = l_b.apply(mapl)
l_r = l_r.apply(mapl)
# Out:
# time: 27.5 ms

# %%
l_b.value_counts()
# Out:
# 0    40591
# 1    12824
# Name: y, dtype: int64
# time: 3.84 ms

# %%
l_r.value_counts()
# Out:
# 0    9796
# 1     197
# Name: y, dtype: int64
# time: 2.79 ms

# %%
data_b = get_labeled_comments(d_b, l_b)
data_r = get_labeled_comments(d_r, l_r)
# Out:
# time: 111 ms

# %% [markdown]
# ### Split into train/dev and test

# %%
b_train, b_test = train_test_split(data_b, test_size = 0.2, random_state=0)
r_train, r_test = train_test_split(data_r, test_size = 0.2, random_state=0)
br_train = pd.concat([b_train, r_train])
br_test = pd.concat([b_test, r_test])
# Out:
# time: 34.1 ms

# %%
len(b_test.merge(b_train, left_index = True, right_index = True, how = 'inner'))
# Out:
# 0
# time: 6.22 ms

# %%
len(r_test.merge(r_train, left_index = True, right_index = True, how = 'inner'))
# Out:
# 0
# time: 3.99 ms

# %%
len(br_test.merge(br_train, left_index = True, right_index = True, how = 'inner'))
# Out:
# 12
# time: 33 ms

# %% [markdown]
# ### NGram Classification Pipeline

# %%
cv_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer(sublinear_tf=True,norm='l2')),
    ('clf', LogisticRegression(solver = 'sag')),
])

param_grid = {
    #'vect__max_df': (0.5, 0.75, 1.0),
    'vect__max_features': (None, 5000, 10000, 50000), #(None, 5000, 10000, 50000),
    'vect__ngram_range': ((1,6),),  
    #'vect_lowercase': (True, False),
    'vect__analyzer' : ('char',), #('word', 'char')
    #'tfidf__use_idf': (True, False),
    #'tfidf__norm': ('l1', 'l2'),
    'clf__C': (0.0001, 0.01, 0.1, 1 ,5,10),
    #'clf__class_weight': ('balanced', None)
}
# Out:
# time: 6.26 ms

# %% [markdown]
# ### Hyper-Parameter tuning

# %%
tune (b_train['x'], b_train['y'], cv_pipeline, param_grid, 'roc_auc', n_jobs=8, verbose=True)
# Out:
# Best parameters set found:
# {'clf__C': 5, 'vect__ngram_range': (1, 6), 'vect__max_features': None, 'vect__analyzer': 'char'} 0.942947737662
#
#
# Grid scores:
# 0.86564 (+/-0.00051) for {'clf__C': 0.0001, 'vect__ngram_range': (1, 6), 'vect__max_features': None, 'vect__analyzer': 'char'}
# 0.85497 (+/-0.00026) for {'clf__C': 0.0001, 'vect__ngram_range': (1, 6), 'vect__max_features': 5000, 'vect__analyzer': 'char'}
# 0.86205 (+/-0.00038) for {'clf__C': 0.0001, 'vect__ngram_range': (1, 6), 'vect__max_features': 10000, 'vect__analyzer': 'char'}
# 0.87068 (+/-0.00055) for {'clf__C': 0.0001, 'vect__ngram_range': (1, 6), 'vect__max_features': 50000, 'vect__analyzer': 'char'}
# 0.88167 (+/-0.00048) for {'clf__C': 0.01, 'vect__ngram_range': (1, 6), 'vect__max_features': None, 'vect__analyzer': 'char'}
# 0.89039 (+/-0.00031) for {'clf__C': 0.01, 'vect__ngram_range': (1, 6), 'vect__max_features': 5000, 'vect__analyzer': 'char'}
# 0.89365 (+/-0.00018) for {'clf__C': 0.01, 'vect__ngram_range': (1, 6), 'vect__max_features': 10000, 'vect__analyzer': 'char'}
# 0.89280 (+/-0.00045) for {'clf__C': 0.01, 'vect__ngram_range': (1, 6), 'vect__max_features': 50000, 'vect__analyzer': 'char'}
# 0.91757 (+/-0.00024) for {'clf__C': 0.1, 'vect__ngram_range': (1, 6), 'vect__max_features': None, 'vect__analyzer': 'char'}
# 0.91955 (+/-0.00050) for {'clf__C': 0.1, 'vect__ngram_range': (1, 6), 'vect__max_features': 5000, 'vect__analyzer': 'char'}
# 0.92451 (+/-0.00002) for {'clf__C': 0.1, 'vect__ngram_range': (1, 6), 'vect__max_features': 10000, 'vect__analyzer': 'char'}
# 0.92521 (+/-0.00025) for {'clf__C': 0.1, 'vect__ngram_range': (1, 6), 'vect__max_features': 50000, 'vect__analyzer': 'char'}
# 0.93974 (+/-0.00011) for {'clf__C': 1, 'vect__ngram_range': (1, 6), 'vect__max_features': None, 'vect__analyzer': 'char'}
# 0.93272 (+/-0.00018) for {'clf__C': 1, 'vect__ngram_range': (1, 6), 'vect__max_features': 5000, 'vect__analyzer': 'char'}
# 0.93772 (+/-0.00006) for {'clf__C': 1, 'vect__ngram_range': (1, 6), 'vect__max_features': 10000, 'vect__analyzer': 'char'}
# 0.94087 (+/-0.00006) for {'clf__C': 1, 'vect__ngram_range': (1, 6), 'vect__max_features': 50000, 'vect__analyzer': 'char'}
# 0.94295 (+/-0.00015) for {'clf__C': 5, 'vect__ngram_range': (1, 6), 'vect__max_features': None, 'vect__analyzer': 'char'}
# 0.93213 (+/-0.00006) for {'clf__C': 5, 'vect__ngram_range': (1, 6), 'vect__max_features': 5000, 'vect__analyzer': 'char'}
# 0.93624 (+/-0.00011) for {'clf__C': 5, 'vect__ngram_range': (1, 6), 'vect__max_features': 10000, 'vect__analyzer': 'char'}
# 0.93916 (+/-0.00011) for {'clf__C': 5, 'vect__ngram_range': (1, 6), 'vect__max_features': 50000, 'vect__analyzer': 'char'}
# 0.94198 (+/-0.00022) for {'clf__C': 10, 'vect__ngram_range': (1, 6), 'vect__max_features': None, 'vect__analyzer': 'char'}
# 0.92964 (+/-0.00016) for {'clf__C': 10, 'vect__ngram_range': (1, 6), 'vect__max_features': 5000, 'vect__analyzer': 'char'}
# 0.93292 (+/-0.00013) for {'clf__C': 10, 'vect__ngram_range': (1, 6), 'vect__max_features': 10000, 'vect__analyzer': 'char'}
# 0.93519 (+/-0.00014) for {'clf__C': 10, 'vect__ngram_range': (1, 6), 'vect__max_features': 50000, 'vect__analyzer': 'char'}
# time: 35min 18s

# %%
## Be very careful to transcribe the correct params
optimal_pipeline = Pipeline([
    ('vect', CountVectorizer(ngram_range = (1,5), analyzer = 'char', max_features = 10000)),
    ('tfidf', TfidfTransformer(sublinear_tf=True,norm='l2')),
    ('clf', LogisticRegression(C = 1.0, class_weight = None)),
])
# Out:
# time: 2.41 ms

# %% [markdown]
# ### Train on blocked

# %%
b_model = optimal_pipeline.fit(b_train['x'], b_train['y'])
# Out:
# time: 1min 6s

# %%
print('Eval on blocked')
_= eval_binary_classifier(b_model, b_test, calibration = False, roc = True)
# Out:
# Eval on blocked
# threshold @ optimal F1: 0.31698934607
# {'optimal F1': '0.760',
#  'precision @ optimal F1': '0.759',
#  'recall @ optimal F1': '0.759',
#  'roc': '0.929'}
# time: 15.1 s

# %%
print('Eval on random')
_= eval_binary_classifier(b_model, r_test, calibration = False, roc = True)
# Out:
# Eval on random
# threshold @ optimal F1: 0.266665696532
# {'optimal F1': '0.463',
#  'precision @ optimal F1': '0.452',
#  'recall @ optimal F1': '0.452',
#  'roc': '0.902'}
# time: 3.08 s

# %% [markdown]
# ### Train on random

# %%
r_model = optimal_pipeline.fit(r_train['x'], r_train['y'])
# Out:
# time: 11.8 s

# %%
print('Eval on blocked')
_= eval_binary_classifier(r_model, b_test, calibration = False, roc = True)
# Out:
# Eval on blocked
# threshold @ optimal F1: 0.0427866509724
# {'optimal F1': '0.625',
#  'precision @ optimal F1': '0.650',
#  'recall @ optimal F1': '0.650',
#  'roc': '0.847'}
# time: 14.9 s

# %%
print('Eval on random')
_= eval_binary_classifier(r_model, r_test, calibration = False, roc = True)
# Out:
# Eval on random
# threshold @ optimal F1: 0.0615439524464
# {'optimal F1': '0.275',
#  'precision @ optimal F1': '0.333',
#  'recall @ optimal F1': '0.333',
#  'roc': '0.884'}
# time: 3.09 s

# %% [markdown]
# ### Train on both

# %%
br_model = optimal_pipeline.fit(br_train['x'], br_train['y'])
# Out:
# time: 1min 17s

# %%
print('Eval on blocked')
_= eval_binary_classifier(br_model, b_test, calibration = False, roc = True)
# Out:
# Eval on blocked
# threshold @ optimal F1: 0.32841183133
# {'optimal F1': '0.758',
#  'precision @ optimal F1': '0.741',
#  'recall @ optimal F1': '0.741',
#  'roc': '0.929'}
# time: 15.1 s

# %%
print('Eval on random')
_= eval_binary_classifier(br_model, r_test, calibration = False, roc = True)
# Out:
# Eval on random
# threshold @ optimal F1: 0.23655335674
# {'optimal F1': '0.463',
#  'precision @ optimal F1': '0.452',
#  'recall @ optimal F1': '0.452',
#  'roc': '0.910'}
# time: 3.29 s

# %%
print('Eval on both')
_= eval_binary_classifier(br_model, br_test, calibration = False, roc = True)
# Out:
# Eval on both
# threshold @ optimal F1: 0.291421572706
# {'optimal F1': '0.754',
#  'precision @ optimal F1': '0.761',
#  'recall @ optimal F1': '0.761',
#  'roc': '0.937'}
# time: 18.9 s

# %% [markdown]
# ### Check Calibration

# %%
_= eval_binary_classifier(br_model, br_test, calibration = True, roc = False)
# Out:
# threshold @ optimal F1: 0.291421572706
# {'optimal F1': '0.754',
#  'precision @ optimal F1': '0.761',
#  'recall @ optimal F1': '0.761',
#  'roc': '0.937'}
# time: 19.3 s

# %%
_= eval_binary_classifier(br_model, b_test, calibration = True, roc = False)
# Out:
# threshold @ optimal F1: 0.32841183133
# {'optimal F1': '0.758',
#  'precision @ optimal F1': '0.741',
#  'recall @ optimal F1': '0.741',
#  'roc': '0.929'}
# time: 16.4 s

# %%
_= eval_binary_classifier(br_model, r_test, calibration = True, roc = False)
# Out:
# threshold @ optimal F1: 0.23655335674
# {'optimal F1': '0.463',
#  'precision @ optimal F1': '0.452',
#  'recall @ optimal F1': '0.452',
#  'roc': '0.910'}
# time: 3.78 s

# %% [markdown]
# ### Error Analysis

# %%
fn, fp = get_clf_errors(br_model, br_test)
# Out:
# time: 34.9 s

# %%
# extreme False negatives
print_clf_errors(fn)
# Out:
# COMMENT:
# HEY C, I AGREE AND THINK THE PERSON WHO STARTED THIS SECTION IS A LIAR TOO, AND I TOLD YA THESE PEOPLE ARE CRAZY!!!!! lol ANYWAY I SEE THAT YOU'RE FROM Atlanta kudos (VERY BEAUTIFUL AND WARM NICE PEOPLE), I READ IN Hip Hop Weekly and heard Wendy Williams SAY THAT THE WORD ON THE STREET OUT THERE IN THE ATL IS THAT Ciara SLEPT WITH Young Jeezy TO FINISH UP NEGOTIATIONS FOR HER CURRENT SINGLE AND VIDEO........ OOOOH ITS A SHAME AND I PERSONALLY THINK SHE DEALT WITH 50 Cent IN 2007 AS WELL lol, IS
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
# They are all cunts It's not worth editing articles here concerning any serious issue. All sides consist of either people employed to edit or people with very strong opinions that will never, ever change. They advocate their stance as something that is interesting to them instead of using the encyclopedia as a book of knowledge and contributing what they are sure to know.  Soon with the centralization of the net into larger and larger sites, independent information in general will be extinguish
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
# "I have repeatedly attempted to communicate with Wikipedia with a simple request.Virtually all attempts have been blocked. I am not appealing for arbitration.My contributions were deemed to be ""original research"", the accusation was made that I had never given a valid citation to support them. I repeatedly posted the citation, even going so far as to quote the text. This was rejected by an editor repeatedly as being without merit despite my requests that said editor at least check the ci
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
# "Reply to your comments on my talk pageYour uncivil tone notwithstanding, I love being proved wrong, so please take this to Wikipedia:Deletion review.  IF you have a problem with my resolution, please submit to the appropriate forum on Wikipedia:Administrators noticeboard.Regarding my decision: the concepts you were trying to present exist in the book's article; greater expounding does not, in my good faith search, exist in any documented form that conforms to our expectations, such as foun
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
# "You must be joking, right? I am not the one who does not have any rational arguments. But, please, dear Kwamikagami, do tell me which of my arguments were irrational? The one in which (1) I have cited several recent linguistic scholarly books from mainstream publishers (Cambridge University Press, Indiana University Press, Wiley Blackwell, Springer, etc.), to demonstrate that the terminology ""Finno-Ugric"" is widely used? Or the one above (2) in which I highlighted that the main department of
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
#  Blocked I blocked you for a week per consensus in WP:AN/I for disruption. Thanks  wat's sup
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
# And I am especially impressed by the way I was blocked AFTER I warning that appeared after I logged out, so I couldn't have possibly breached that warning. I see that Wikipaedia is still a complete fail.
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
# Correct mistakes?The repeated deletion without warning of my in-progress article stub was destructive to the Wikipedia community spirit, and I'm glad that the perpetrator decided on further reflection to insert a warning of possible deletion instead.  The deleter made mistakes; corrected the mistakes; life goes on.  However, the demeaning tone used, and threats to blocking the contributor, live on.  When will that mistake be corrected?  I suggest an apology.
# SCORES: Actual: 1, Predicted: 0, Score: 0.02
#
#
# COMMENT:
# " Falsely claiming that I ""have continued with the same behavior"", eh? I'd like to know if you always lie that way, or if you just feel like lying on occasion. Oh, I'm sorry, I guess it might just be incompetence and not the willful lying it appears to be. Either way, it isn't true.  "
# SCORES: Actual: 1, Predicted: 0, Score: 0.03
#
#
# COMMENT:
#  What edit war? I'm not involved in any edit war at all. Please don't make false claims against other editors. -
# SCORES: Actual: 1, Predicted: 0, Score: 0.03
#
#
# time: 2.48 ms

# %%
# extreme False positives
print_clf_errors(fp)
# Out:
# COMMENT:
#  way to be racist racist asshole
# SCORES: Actual: 0, Predicted: 1, Score: 0.98
#
#
# COMMENT:
#  HEY BUTTFACE YOUR A STUPID LIKE TIMBERLY ELIZABETH BUTTFACE YOU BUTTACE
# SCORES: Actual: 0, Predicted: 1, Score: 0.98
#
#
# COMMENT:
# Be nice and don't be a dick, or I will kick your ass.
# SCORES: Actual: 0, Predicted: 1, Score: 0.98
#
#
# COMMENT:
# Please do, suck my cock.
# SCORES: Actual: 0, Predicted: 1, Score: 0.97
#
#
# COMMENT:
#  You Are an *****le!
# SCORES: Actual: 0, Predicted: 1, Score: 0.97
#
#
# COMMENT:
# my name is reaper eternal and i am a stupid dumasss small dik retard
# SCORES: Actual: 0, Predicted: 1, Score: 0.97
#
#
# COMMENT:
#  With Regards to Your Recent Thoughtful Epistle... Go get fucked and maybe you will not be so goddamned gay. Otherwise, go eat a bag of hell and drop dead.
# SCORES: Actual: 0, Predicted: 1, Score: 0.96
#
#
# COMMENT:
# Actually, since I'm just a little bitch, I'm gonna go ahead and block you now. I'm such a FAG!
# SCORES: Actual: 0, Predicted: 1, Score: 0.96
#
#
# COMMENT:
# Rodeo Song lyricsWell it's 40 below and I don't give a fuckGot a heater in my truck and I'm off to the rodeoAnd it's allemande left and allemande rightCome on ya fuckin' dummy get your right step rightGet off the stage ya god damn goof, get offpiss me off, fuckin' jerk, get on my nervesWell here comes Johnny with his pecker in his handHe's a one ball man and he's off to the rodeoAnd it's allemande left and allemande rightCome on ya fuckin' dummy get your right step rightGet off the
# SCORES: Actual: 0, Predicted: 1, Score: 0.95
#
#
# COMMENT:
#  Wow dude you blocked me for stupid stuff I made an edit and I get this warning fix this shit dang Bots Your bot is a peice of shit and it's reverts are counter productive.  It is moronic for you to leave an automated crapbot running.   22:30, 28 May 2006 (UTC)
# SCORES: Actual: 0, Predicted: 1, Score: 0.95
#
#
# time: 3.17 ms

# %% [markdown]
# ### Learning Curves!
# Split blocked data into train and test. Train on a portion of train and test on test. This shows how well we do on blocked dat as we add more training data.

# %%
def get_roc(model, test):
    return roc_auc_score(test['y'], model.predict_proba(test['x'])[:, 1])
# Out:
# time: 19.7 ms

# %%
ms, metrics = eval_adding_other_data(optimal_pipeline, None, b_test, b_train, get_roc, test_size = 0.5)
plot_adding_other_data(ms, metrics)
# Out:
# time: 5min 22s

# %% [markdown]
# ### How does adding blocked data change performance on random data?
#
# Incrementally add blocked data to full random data set on training. Eval on held out blocked data.

# %%
ms, metrics = eval_adding_other_data(optimal_pipeline, r_train, r_test, b_train, get_roc, test_size = 0.8)
plot_adding_other_data(ms, metrics)
# Out:
# time: 9min 9s

# %% [markdown]
# ### How does adding random data change performance on blocked data?
#
# Incrementally add random data to full blocked data set on training. Eval on held out blocked data.

# %%
ms, metrics = eval_adding_other_data(optimal_pipeline, b_train, b_test, r_train, get_roc, test_size = 0.8)
plot_adding_other_data(ms, metrics)
# Out:
# time: 23min 2s

# %% [markdown]
# # Final Model

# %%
br_data = pd.concat([data_r,data_b])
final_model = optimal_pipeline.fit(br_data['x'], br_data['y'])
joblib.dump(final_model, '../../models/%s_ngram.pkl' % task)
# Out:
# ['../../models/recipient_ngram.pkl',
#  '../../models/recipient_ngram.pkl_01.npy',
#  '../../models/recipient_ngram.pkl_02.npy',
#  '../../models/recipient_ngram.pkl_03.npy',
#  '../../models/recipient_ngram.pkl_04.npy',
#  '../../models/recipient_ngram.pkl_05.npy',
#  '../../models/recipient_ngram.pkl_06.npy']
# time: 1min 50s

# %% [markdown]
# # Model Understanding

# %%
understanding_pipeline = Pipeline([
    ('vect', CountVectorizer(ngram_range = (1,1), analyzer = 'word', max_features = 10000)),
    ('tfidf', TfidfTransformer(sublinear_tf=True,norm='l2')),
    ('clf', LogisticRegression(C = 1.0, class_weight = None)),
])
# Out:
# time: 1.95 ms

# %%
model = understanding_pipeline.fit(br_train['x'], br_train['y'])
# Out:
# time: 3.27 s

# %%
clf = model.named_steps['clf']
# Out:
# time: 800 µs

# %%
coef_ = clf.coef_.ravel()
# Out:
# time: 957 µs

# %%
feature_names = np.array(model.named_steps['vect'].get_feature_names())
# Out:
# time: 14.7 ms

# %%
most_pos_idx = np.argsort(coef_)[-100:]
most_pos = feature_names[most_pos_idx]
# Out:
# time: 1.72 ms

# %%
most_neg_idx = np.argsort(coef_)[:100]
most_neg = feature_names[most_neg_idx]
# Out:
# time: 1.82 ms

# %%
most_pos
# Out:
# array(['damn', 'quit', 'shove', 'arsehole', 'dicks', 'nazis', 'ты',
#        'homosexual', 'fat', 'pig', 'fuc', 'stop', 'disgusting', 'anal',
#        'face', 'yo', 'hate', 'fc', 'retarded', 'piss', 'lick', 'arse',
#        'douche', 'head', 'wanker', 'smell', 'dickhead', 'jackass', 'penis',
#        'balls', 'ck', 'fuckers', 'arrogant', 'life', 'nazi', 'pussy',
#        'prick', 'ing', 'are', 'nigga', 'jerk', 'sex', 'youre', 'hole',
#        'fuk', 'scum', 'nigger', 'gay', 'idiotic', 'yourself', 'douchebag',
#        'kiss', 'little', 'fuckin', 'loser', 'fag', 'screw', 'dumbass',
#        'bullshit', 'pathetic', 'ugly', 'cocksucker', 'coward', 'crap',
#        'hypocrite', 'assholes', 'ignorant', 'hell', 'ur', 'idiots',
#        'motherfucker', 'retard', 'kill', 'dumb', 'fuckhead', 'racist',
#        'go', 'fucked', 'fool', 'off', 'faggot', 'cock', 'die', 'cunt',
#        'shut', 'fucker', 'bastard', 'dick', 'ass', 'moron', 'bitch',
#        'shit', 'suck', 'your', 'asshole', 'stupid', 'idiot', 'fucking',
#        'you', 'fuck'],
#       dtype='<U173')
# time: 1.99 ms

# %%
most_neg
# Out:
# array(['thank', 'help', 'thanks', 'please', 'he', 'talk', 'to', 'they',
#        'this', 'for', 'user', 'appreciate', 'if', 'song', 'articles',
#        'issue', 'but', 'request', 'hi', 'him', 'welcome', 'love',
#        'discussion', 'the', 'see', 'interested', 'billcj', 'against',
#        'position', 'agree', 'username', 'comment', 'continue', 'suggest',
#        'understand', 'might', 'at', 'reported', 'these', 'rfa', 'can',
#        'great', 'cannot', 'riot', 'interesting', 'cool', 'notice', 'title',
#        'section', 'editing', 'should', 'questions', 'hes', 'utc',
#        'knowledge', 'al', 'is', 'saying', 'fix', 'article', 'work',
#        'could', 'cheers', 'yes', 'response', 'we', 'also', 'there',
#        'blocked', 'new', 'particular', 'from', 'music', 'dreadstar',
#        'once', 'notable', 'through', 'simply', 'his', '2006',
#        'contributions', 'summaries', 'currently', 'evidence', 'would',
#        'january', 'link', 'more', 'luck', 'done', 'list', 'include',
#        'worry', 'did', 'point', 'used', 'posting', 'further', 'note', 'it'],
#       dtype='<U173')
# time: 1.85 ms

# %%
"""
coef = coef_.ravel()[important]
inds = np.argsort(coef)
f_imp = f_imp[inds]
coef = coef[inds]
plt.plot(coef, label="l1")
ax = plt.gca()
ax.set_xticks(np.arange(len(coef)))
labels = ax.set_xticklabels(f_imp)
for label in labels:
    label.set_rotation(90)
plt.show()

"""
# Out:
# time: 644 ms
